# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('corr_bio_env_heatmap_M0_srf.tsv', sep='\t', index_col=0)
plt.plot(np.sort(abs(df.Temperature)))

# %%
lista = ', '.join(df[abs(df['Temperature']) >= 0.5].Temperature.index.tolist())
print(lista)
# Out:
# AgaR, CsoR, FUR, FabR, GguR, GntR, GulR, HrcA, KdgR, LiuR, MetR, NagC, NnrR, NtrC, RbkR, SahR_SamR, ThiR

# %%
df.columns
# Out:
# Index(['Latitude', 'Longitude', 'Temperature', 'Oxygen', 'ChlorophyllA',
#        'Salinity', 'Carbon.total', 'NO2', 'NO2NO3', 'NO3', 'PO4',
#        'Ammonium.5m', 'Iron.5m', 'Alkalinity.total', 'CO3', 'HCO3', 'Lyapunov',
#        'Si', 'Nitracline', 'Brunt.Väisälä', 'Okubo.Weiss', 'Residence.time',
#        'PAR.PC', 'Gradient.Surface.temp(SST)', 'Fluorescence', 'Density',
#        'Depth.Min.O2', 'Depth.Max.O2', 'Mean Flux at 150m', 'FluxAttenuation',
#        'NPP 8d VGPM (mgC/m2/day)'],
#       dtype='object')

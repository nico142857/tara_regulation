# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

import seaborn as sns

from xgboost import XGBClassifier

from sklearn.model_selection import train_test_split, cross_val_score, RepeatedStratifiedKFold
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import f1_score

from tqdm import tqdm

# %% [markdown]
# # Upload metadata

# %%
md = pd.read_csv('../matrices/metadata.tsv', sep='\t', index_col=0)
md.head()
# Out:
#          PANGAEA sample id Station.label Layer Layer2      polar  \
# TSC_NAME
# TSC000     TARA_X000000368      TARA_004   DCM    EPI  non polar
# TSC001     TARA_Y200000002      TARA_004   SRF    EPI  non polar
# TSC002     TARA_A200000159      TARA_007   DCM    EPI  non polar
# TSC003     TARA_A200000113      TARA_007   SRF    EPI  non polar
# TSC004     TARA_X000001036      TARA_009   DCM    EPI  non polar
#
#           lower.size.fraction  upper.size.fraction        Event.date  \
# TSC_NAME
# TSC000                   0.22                  1.6  2009-09-15 18:00
# TSC001                   0.22                  1.6  2009-09-15 11:30
# TSC002                   0.22                  1.6  2009-09-23 16:08
# TSC003                   0.22                  1.6  2009-09-23 12:50
# TSC004                   0.22                  1.6  2009-09-28 16:59
#
#           Latitude  Longitude  ...  Gradient.Surface.temp(SST)  Fluorescence  \
# TSC_NAME                       ...
# TSC000     36.5533    -6.5669  ...                     0.85990           NaN
# TSC001     36.5533    -6.5669  ...                     0.73994           NaN
# TSC002     37.0541     1.9478  ...                     1.03750           NaN
# TSC003     37.0510     1.9378  ...                     1.03750           NaN
# TSC004     39.0609     5.9422  ...                     0.35542           NaN
#
#             Density  Depth.Min.O2  Depth.Max.O2  Mean Flux at 150m  \
# TSC_NAME
# TSC000    26.886600           NaN           NaN                NaN
# TSC001    25.909909           NaN           NaN                NaN
# TSC002    27.003675           NaN           NaN                NaN
# TSC003    25.611150           NaN           NaN                NaN
# TSC004    27.816050           NaN           NaN                NaN
#
#           FluxAttenuation  NPP 8d VGPM (mgC/m2/day)  \
# TSC_NAME
# TSC000                NaN                       NaN
# TSC001                NaN                  686.0860
# TSC002                NaN                  354.2245
# TSC003                NaN                  354.2245
# TSC004                NaN                  205.1220
#
#                                             Ocean  Province
# TSC_NAME
# TSC000    [NAO] North Atlantic Ocean (MRGID:1912)       NaN
# TSC001    [NAO] North Atlantic Ocean (MRGID:1912)        B7
# TSC002        [MS] Mediterranean Sea (MRGID:1905)       NaN
# TSC003        [MS] Mediterranean Sea (MRGID:1905)        B7
# TSC004        [MS] Mediterranean Sea (MRGID:1905)       NaN
#
# [5 rows x 44 columns]

# %% [markdown]
# # Bins of environmental variables

# %%
bins_temperature = [-np.inf, 10, 22, np.inf]
labels_temperature = ['<10', '10-22', '>22']
md['Temperature_binned'] = pd.cut(md['Temperature'], bins=bins_temperature, labels=labels_temperature)

bins_oxygen = [-np.inf, 185, 250, np.inf]
labels_oxygen = ['<185', '185-250', '>250']
md['Oxygen_binned'] = pd.cut(md['Oxygen'], bins=bins_oxygen, labels=labels_oxygen)

md['ChlorophyllA_binned'] = np.where(md['ChlorophyllA'] <= 0.28, '<=0.28', '>0.28')

md['Fluorescence_binned'] = np.where(md['Fluorescence'] <= 2.3, '<=2.3', '>2.3')

bins_salinity = [-np.inf, 34, 37, np.inf]
labels_salinity = ['<=34', '34-37', '>37']
md['Salinity_binned'] = pd.cut(md['Salinity'], bins=bins_salinity, labels=labels_salinity)

md['NO3_binned'] = np.where(md['NO3'] <= 7, '<=7', '>7')

bins_flux = [-np.inf, 0.7, 3, np.inf]
labels_flux = ['<=0.7', '0.7-3', '>3']
md['Mean_Flux_150m_binned'] = pd.cut(md['Mean Flux at 150m'], bins=bins_flux, labels=labels_flux)

bins_npp = [-np.inf, 275, 540, np.inf]
labels_npp = ['<=275', '275-540', '>540']
md['NPP_binned'] = pd.cut(md['NPP 8d VGPM (mgC/m2/day)'], bins=bins_npp, labels=labels_npp)

# %% [markdown]
# # CLR implementation

# %%
def clr_(data, eps=1e-6):
    """
    Perform centered log-ratio (clr) normalization on a dataset.

    Parameters:
    data (pandas.DataFrame): A DataFrame with samples as rows and components as columns.

    Returns:
    pandas.DataFrame: A clr-normalized DataFrame.
    """
    if (data < 0).any().any():
        raise ValueError("Data should be strictly positive for clr normalization.")

    # Add small amount to cells with a value of 0
    if (data <= 0).any().any():
        data = data.replace(0, eps)

    # Calculate the geometric mean of each row
    gm = np.exp(data.apply(np.log).mean(axis=1))

    # Perform clr transformation
    clr_data = data.apply(np.log).subtract(np.log(gm), axis=0)

    return clr_data

# %% [markdown]
# # Model

# %%
matrices = ['Matrix_MX_all', 'Matrix_M1_all', 'Matrix_M0_all', 'Matrix_guidi_all', 'Matrix_salazar_all', 'Matrix_stress_all',
           'Matrix_GEN_M4_all', 'Matrix_GEN_M0_all', 'Matrix_GEN_guidi_all', 'Matrix_GEN_salazar_all', 'Matrix_GEN_stress_all'
           ]
variables = ['polar', 'Layer', 'Layer2', 'Province', 'Temperature_binned', 'Oxygen_binned', 'ChlorophyllA_binned', 'Fluorescence_binned', 'Salinity_binned', 'NO3_binned', 'Mean_Flux_150m_binned', 'NPP_binned']
#variables = ['Temperature_binned', 'Oxygen_binned']
num_cycles = 100  # Number of cycles to run

results = []

# Label encoder instance
label_encoder = LabelEncoder()

# Iterate over each matrix and variable to train the model
for matrix_name in tqdm(matrices, desc='Processing matrices'):
    matrix = pd.read_csv(f'../matrices/{matrix_name}.tsv', sep='\t', index_col=0)
    matrix = clr_(matrix)  # Apply clr transformation
    
    for variable in tqdm(variables, desc=f'Variables in {matrix_name}', leave=False):
        X = matrix
        y = label_encoder.fit_transform(md[variable])  # Encode labels
        
        # Store f1 scores for each cycle
        f1_scores = []

        for cycle in tqdm(range(num_cycles), desc='Simulation cycles', leave=False):
            # Split the data into training and testing sets with a different random state each time
            X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=cycle)

            # Create and train the model
            model = XGBClassifier(n_estimators=250)
            model.fit(X_train, y_train)

            # Evaluate the model
            y_pred = model.predict(X_test)
            score = f1_score(y_test, y_pred, average='weighted')
            f1_scores.append(score)

        # Compute average F1 score over all cycles
        avg_f1_score = np.mean(f1_scores)
        results.append(('_'.join(matrix_name.split('_')[1:]), variable, avg_f1_score))

# Filename
output_file = 'initial_prediction_tf_vs_gen'
# Directory
out_dir = '../../out_results/out_initial_predictions/'
        
df_results = pd.DataFrame(results, columns=['matrix_type', 'target_variable', 'f1_score'])
df_results.to_csv(out_dir+output_file+'.tsv', sep='\t', index=False)

# Display the results
for result in results:
    print(f'Matrix: {result[0]}, Variable: {result[1]}, Average F1 Score over {num_cycles} cycles: {result[2]:.4f}')
# Out:
# Processing matrices:   0%|          | 0/11 [00:00<?, ?it/s]
# Variables in Matrix_MX_all:   0%|          | 0/12 [00:00<?, ?it/s]
#
# Simulation cycles:   0%|          | 0/100 [00:00<?, ?it/s]
#
# Simulation cycles:   2%|▏         | 2/100 [00:00<00:08, 11.12it/s]
#
# Simulation cycles:   4%|▍         | 4/100 [00:00<00:07, 12.23it/s]
#
# Simulation cycles:   6%|▌         | 6/100 [00:00<00:07, 12.48it/s]
#
# Simulation cycles:   8%|▊         | 8/100 [00:00<00:07, 12.45it/s]
#
# Simulation cycles:  10%|█         | 10/100 [00:00<00:06, 12.92it/s]
#
# Simulation cycles:  12%|█▏        | 12/100 [00:00<00:06, 12.75it/s]
#
# Simulation cycles:  14%|█▍        | 14/100 [00:01<00:06, 12.60it/s]
#
# Simulation cycles:  16%|█▌        | 16/100 [00:01<00:06, 12.25it/s]
#
# Simulation cycles:  18%|█▊        | 18/100 [00:01<00:07, 11.14it/s]
#
# Simulation cycles:  20%|██        | 20/100 [00:01<00:07, 11.24it/s]
#
# Simulation cycles:  22%|██▏       | 22/100 [00:01<00:06, 11.76it/s]
#
# Simulation cycles:  24%|██▍       | 24/100 [00:02<00:06, 11.62it/s]
#
# Simulation cycles:  26%|██▌       | 26/100 [00:02<00:06, 11.38it/s]
#
# Simulation cycles:  28%|██▊       | 28/100 [00:02<00:06, 11.70it/s]
#
# Simulation cycles:  30%|███       | 30/100 [00:02<00:05, 12.15it/s]
#
# Simulation cycles:  32%|███▏      | 32/100 [00:02<00:05, 12.32it/s]
#
# Simulation cycles:  34%|███▍      | 34/100 [00:02<00:05, 12.24it/s]
#
# Simulation cycles:  36%|███▌      | 36/100 [00:02<00:05, 12.40it/s]
#
# Simulation cycles:  38%|███▊      | 38/100 [00:03<00:04, 12.67it/s]
#
# Simulation cycles:  40%|████      | 40/100 [00:03<00:04, 12.83it/s]
#
# Simulation cycles:  42%|████▏     | 42/100 [00:03<00:04, 13.16it/s]
#
# Simulation cycles:  44%|████▍     | 44/100 [00:03<00:04, 13.13it/s]
#
# Simulation cycles:  46%|████▌     | 46/100 [00:03<00:04, 13.13it/s]
#
# Simulation cycles:  48%|████▊     | 48/100 [00:03<00:03, 13.13it/s]
#
# Simulation cycles:  50%|█████     | 50/100 [00:04<00:04, 12.22it/s]
#
# Simulation cycles:  52%|█████▏    | 52/100 [00:04<00:03, 12.14it/s]
#
# Simulation cycles:  54%|█████▍    | 54/100 [00:04<00:03, 12.33it/s]
#
# Simulation cycles:  56%|█████▌    | 56/100 [00:04<00:03, 12.57it/s]
#
# Simulation cycles:  58%|█████▊    | 58/100 [00:04<00:03, 12.95it/s]
#
# Simulation cycles:  60%|██████    | 60/100 [00:04<00:03, 11.99it/s]
#
# Simulation cycles:  62%|██████▏   | 62/100 [00:05<00:03, 11.53it/s]
#
# Simulation cycles:  64%|██████▍   | 64/100 [00:05<00:03, 11.13it/s]
#
# Simulation cycles:  66%|██████▌   | 66/100 [00:05<00:02, 11.37it/s]
#
# Simulation cycles:  68%|██████▊   | 68/100 [00:05<00:02, 11.70it/s]
#
# Simulation cycles:  70%|███████   | 70/100 [00:05<00:02, 11.73it/s]
#
# Simulation cycles:  72%|███████▏  | 72/100 [00:05<00:02, 12.18it/s]
#
# Simulation cycles:  74%|███████▍  | 74/100 [00:06<00:02, 12.39it/s]
#
# Simulation cycles:  76%|███████▌  | 76/100 [00:06<00:01, 12.28it/s]
#
# Simulation cycles:  78%|███████▊  | 78/100 [00:06<00:01, 12.79it/s]
#
# Simulation cycles:  80%|████████  | 80/100 [00:06<00:01, 12.21it/s]
#
# Simulation cycles:  82%|████████▏ | 82/100 [00:06<00:01, 12.31it/s]
#
# Simulation cycles:  84%|████████▍ | 84/100 [00:06<00:01, 12.45it/s]
#
# Simulation cycles:  86%|████████▌ | 86/100 [00:07<00:01, 12.49it/s]
#
# Simulation cycles:  88%|████████▊ | 88/100 [00:07<00:00, 12.57it/s]
#
# Simulation cycles:  90%|█████████ | 90/100 [00:07<00:00, 12.94it/s]
#
# Simulation cycles:  92%|█████████▏| 92/100 [00:07<00:00, 12.25it/s]
#
# Simulation cycles:  94%|█████████▍| 94/100 [00:07<00:00, 12.09it/s]
#
# Simulation cycles:  96%|█████████▌| 96/100 [00:07<00:00, 12.28it/s]
#
# Simulation cycles:  98%|█████████▊| 98/100 [00:08<00:00, 12.33it/s]
#
# Simulation cycles: 100%|██████████| 100/100 [00:08<00:00, 12.41it/s]
#
#
# Variables in Matrix_MX_all:   8%|▊         | 1/12 [00:08<01:29,  8.17s/it]
#
# Simulation cycles:   0%|          | 0/100 [00:00<?, ?it/s]
#
# Simulation cycles:   1%|          | 1/100 [00:00<00:18,  5.41it/s]
#
# Simulation cycles:   2%|▏         | 2/100 [00:00<00:17,  5.52it/s]
#
# Simulation cycles:   3%|▎         | 3/100 [00:00<00:17,  5.44it/s]
#
# Simulation cycles:   4%|▍         | 4/100 [00:00<00:17,  5.50it/s]
#
# Simulation cycles:   5%|▌         | 5/100 [00:00<00:16,  5.71it/s]
#
# Simulation cycles:   6%|▌         | 6/100 [00:01<00:16,  5.73it/s]
#
# Simulation cycles:   7%|▋         | 7/100 [00:01<00:16,  5.73it/s]
#
# Simulation cycles:   8%|▊         | 8/100 [00:01<00:16,  5.53it/s]
#
# Simulation cycles:   9%|▉         | 9/100 [00:01<00:16,  5.37it/s]
#
# Simulation cycles:  10%|█         | 10/100 [00:01<00:17,  5.24it/s]
#
# Simulation cycles:  11%|█         | 11/100 [00:02<00:16,  5.35it/s]
#
# Simulation cycles:  12%|█▏        | 12/100 [00:02<00:16,  5.26it/s]
#
# Simulation cycles:  13%|█▎        | 13/100 [00:02<00:16,  5.22it/s]
#
# Simulation cycles:  14%|█▍        | 14/100 [00:02<00:17,  4.93it/s]
#
# Simulation cycles:  15%|█▌        | 15/100 [00:02<00:17,  4.89it/s]
#
# Simulation cycles:  16%|█▌        | 16/100 [00:03<00:17,  4.82it/s]
#
# Simulation cycles:  17%|█▋        | 17/100 [00:03<00:17,  4.81it/s]
#
# Simulation cycles:  18%|█▊        | 18/100 [00:03<00:16,  4.87it/s]
#
# Simulation cycles:  19%|█▉        | 19/100 [00:03<00:16,  4.96it/s]
#
# Simulation cycles:  20%|██        | 20/100 [00:03<00:15,  5.02it/s]
#
# Simulation cycles:  21%|██        | 21/100 [00:04<00:15,  5.15it/s]
#
# Simulation cycles:  22%|██▏       | 22/100 [00:04<00:14,  5.39it/s]
#
# Simulation cycles:  23%|██▎       | 23/100 [00:04<00:14,  5.38it/s]
#
# Simulation cycles:  24%|██▍       | 24/100 [00:04<00:13,  5.52it/s]
#
# Simulation cycles:  25%|██▌       | 25/100 [00:04<00:13,  5.52it/s]
#
# Simulation cycles:  26%|██▌       | 26/100 [00:04<00:13,  5.66it/s]
#
# Simulation cycles:  27%|██▋       | 27/100 [00:05<00:13,  5.60it/s]
#
# Simulation cycles:  28%|██▊       | 28/100 [00:05<00:12,  5.62it/s]
#
# Simulation cycles:  29%|██▉       | 29/100 [00:05<00:12,  5.55it/s]
#
# Simulation cycles:  30%|███       | 30/100 [00:05<00:12,  5.65it/s]
#
# Simulation cycles:  31%|███       | 31/100 [00:05<00:12,  5.61it/s]
#
# Simulation cycles:  32%|███▏      | 32/100 [00:05<00:12,  5.66it/s]
#
# Simulation cycles:  33%|███▎      | 33/100 [00:06<00:11,  5.78it/s]
#
# Simulation cycles:  34%|███▍      | 34/100 [00:06<00:11,  5.77it/s]
#
# Simulation cycles:  35%|███▌      | 35/100 [00:06<00:12,  5.07it/s]
#
# Simulation cycles:  36%|███▌      | 36/100 [00:06<00:14,  4.54it/s]
#
# Simulation cycles:  37%|███▋      | 37/100 [00:07<00:13,  4.69it/s]
#
# Simulation cycles:  38%|███▊      | 38/100 [00:07<00:13,  4.61it/s]
#
# Simulation cycles:  39%|███▉      | 39/100 [00:07<00:13,  4.53it/s]
#
# Simulation cycles:  40%|████      | 40/100 [00:07<00:12,  4.65it/s]
#
# Simulation cycles:  41%|████      | 41/100 [00:07<00:13,  4.34it/s]
#
# Simulation cycles:  42%|████▏     | 42/100 [00:08<00:13,  4.40it/s]
#
# Simulation cycles:  43%|████▎     | 43/100 [00:08<00:12,  4.58it/s]
#
# Simulation cycles:  44%|████▍     | 44/100 [00:08<00:12,  4.56it/s]
#
# Simulation cycles:  45%|████▌     | 45/100 [00:08<00:11,  4.76it/s]
#
# Simulation cycles:  46%|████▌     | 46/100 [00:09<00:12,  4.44it/s]
#
# Simulation cycles:  47%|████▋     | 47/100 [00:09<00:12,  4.40it/s]
#
# Simulation cycles:  48%|████▊     | 48/100 [00:09<00:11,  4.61it/s]
#
# Simulation cycles:  49%|████▉     | 49/100 [00:09<00:10,  4.70it/s]
#
# Simulation cycles:  50%|█████     | 50/100 [00:09<00:10,  4.97it/s]
#
# Simulation cycles:  51%|█████     | 51/100 [00:10<00:09,  5.08it/s]
#
# Simulation cycles:  52%|█████▏    | 52/100 [00:10<00:09,  5.18it/s]
#
# Simulation cycles:  53%|█████▎    | 53/100 [00:10<00:09,  5.21it/s]
#
# Simulation cycles:  54%|█████▍    | 54/100 [00:10<00:08,  5.25it/s]
#
# Simulation cycles:  55%|█████▌    | 55/100 [00:10<00:08,  5.41it/s]
#
# Simulation cycles:  56%|█████▌    | 56/100 [00:10<00:08,  5.47it/s]
#
# Simulation cycles:  57%|█████▋    | 57/100 [00:11<00:08,  5.29it/s]
#
# Simulation cycles:  58%|█████▊    | 58/100 [00:11<00:07,  5.35it/s]
#
# Simulation cycles:  59%|█████▉    | 59/100 [00:11<00:07,  5.53it/s]
#
# Simulation cycles:  60%|██████    | 60/100 [00:11<00:07,  5.39it/s]
#
# Simulation cycles:  61%|██████    | 61/100 [00:11<00:07,  5.17it/s]
#
# Simulation cycles:  62%|██████▏   | 62/100 [00:12<00:07,  5.06it/s]
#
# Simulation cycles:  63%|██████▎   | 63/100 [00:12<00:07,  5.08it/s]
#
# Simulation cycles:  64%|██████▍   | 64/100 [00:12<00:07,  4.57it/s]
#
# Simulation cycles:  65%|██████▌   | 65/100 [00:12<00:07,  4.46it/s]
#
# Simulation cycles:  66%|██████▌   | 66/100 [00:13<00:07,  4.30it/s]
#
# Simulation cycles:  67%|██████▋   | 67/100 [00:13<00:07,  4.45it/s]
#
# Simulation cycles:  68%|██████▊   | 68/100 [00:13<00:07,  4.46it/s]
#
# Simulation cycles:  69%|██████▉   | 69/100 [00:13<00:06,  4.51it/s]
#
# Simulation cycles:  70%|███████   | 70/100 [00:13<00:06,  4.69it/s]
#
# Simulation cycles:  71%|███████   | 71/100 [00:14<00:05,  4.91it/s]
#
# Simulation cycles:  72%|███████▏  | 72/100 [00:14<00:05,  4.95it/s]
#
# Simulation cycles:  73%|███████▎  | 73/100 [00:14<00:05,  5.14it/s]
#
# Simulation cycles:  74%|███████▍  | 74/100 [00:14<00:05,  5.17it/s]
#
# Simulation cycles:  75%|███████▌  | 75/100 [00:14<00:04,  5.12it/s]
#
# Simulation cycles:  76%|███████▌  | 76/100 [00:15<00:04,  5.17it/s]
#
# Simulation cycles:  77%|███████▋  | 77/100 [00:15<00:04,  5.24it/s]
#
# Simulation cycles:  78%|███████▊  | 78/100 [00:15<00:04,  5.36it/s]
#
# Simulation cycles:  79%|███████▉  | 79/100 [00:15<00:03,  5.40it/s]
#
# Simulation cycles:  80%|████████  | 80/100 [00:15<00:03,  5.42it/s]
#
# Simulation cycles:  81%|████████  | 81/100 [00:15<00:03,  5.17it/s]
#
# Simulation cycles:  82%|████████▏ | 82/100 [00:16<00:03,  4.95it/s]
#
# Simulation cycles:  83%|████████▎ | 83/100 [00:16<00:03,  4.70it/s]
#
# Simulation cycles:  84%|████████▍ | 84/100 [00:16<00:03,  4.58it/s]
#
# Simulation cycles:  85%|████████▌ | 85/100 [00:16<00:03,  4.54it/s]
#
# Simulation cycles:  86%|████████▌ | 86/100 [00:17<00:03,  4.36it/s]
#
# Simulation cycles:  87%|████████▋ | 87/100 [00:17<00:02,  4.59it/s]
#
# Simulation cycles:  88%|████████▊ | 88/100 [00:17<00:02,  4.75it/s]
#
# Simulation cycles:  89%|████████▉ | 89/100 [00:17<00:02,  4.92it/s]
#
# Simulation cycles:  90%|█████████ | 90/100 [00:17<00:02,  4.97it/s]
#
# Simulation cycles:  91%|█████████ | 91/100 [00:18<00:01,  4.89it/s]
#
# Simulation cycles:  92%|█████████▏| 92/100 [00:18<00:01,  4.92it/s]
#
# Simulation cycles:  93%|█████████▎| 93/100 [00:18<00:01,  4.94it/s]
#
# Simulation cycles:  94%|█████████▍| 94/100 [00:18<00:01,  4.98it/s]
#
# Simulation cycles:  95%|█████████▌| 95/100 [00:18<00:01,  4.91it/s]
#
# Simulation cycles:  96%|█████████▌| 96/100 [00:19<00:00,  4.65it/s]
#
# Simulation cycles:  97%|█████████▋| 97/100 [00:19<00:00,  4.33it/s]
#
# Simulation cycles:  98%|█████████▊| 98/100 [00:19<00:00,  4.59it/s]
#
# Simulation cycles:  99%|█████████▉| 99/100 [00:19<00:00,  4.58it/s]
#
# Simulation cycles: 100%|██████████| 100/100 [00:20<00:00,  4.61it/s]
#
#
# Variables in Matrix_MX_all:  17%|█▋        | 2/12 [00:28<02:31, 15.17s/it]
#
# Simulation cycles:   0%|          | 0/100 [00:00<?, ?it/s]
#
# Simulation cycles:   1%|          | 1/100 [00:00<00:09,  9.95it/s]
#
# Simulation cycles:   3%|▎         | 3/100 [00:00<00:08, 11.39it/s]
#
# Simulation cycles:   5%|▌         | 5/100 [00:00<00:08, 11.02it/s]
#
# Simulation cycles:   7%|▋         | 7/100 [00:00<00:08, 11.07it/s]
#
# Simulation cycles:   9%|▉         | 9/100 [00:00<00:08, 11.10it/s]
#
# Simulation cycles:  11%|█         | 11/100 [00:00<00:07, 11.30it/s]
#
# Simulation cycles:  13%|█▎        | 13/100 [00:01<00:07, 11.14it/s]
#
# Simulation cycles:  15%|█▌        | 15/100 [00:01<00:07, 11.37it/s]
#
# Simulation cycles:  17%|█▋        | 17/100 [00:01<00:07, 11.31it/s]
#
# Simulation cycles:  19%|█▉        | 19/100 [00:01<00:07, 11.49it/s]
#
# Simulation cycles:  21%|██        | 21/100 [00:01<00:06, 11.49it/s]
#
# Simulation cycles:  23%|██▎       | 23/100 [00:02<00:06, 11.45it/s]
#
# Simulation cycles:  25%|██▌       | 25/100 [00:02<00:06, 11.74it/s]
#
# Simulation cycles:  27%|██▋       | 27/100 [00:02<00:06, 11.77it/s]
#
# Simulation cycles:  29%|██▉       | 29/100 [00:02<00:06, 11.49it/s]
#
# Simulation cycles:  31%|███       | 31/100 [00:02<00:05, 11.66it/s]
#
# Simulation cycles:  33%|███▎      | 33/100 [00:02<00:05, 11.87it/s]
#
# Simulation cycles:  35%|███▌      | 35/100 [00:03<00:05, 12.15it/s]
#
# Simulation cycles:  37%|███▋      | 37/100 [00:03<00:05, 12.14it/s]
#
# Simulation cycles:  39%|███▉      | 39/100 [00:03<00:05, 12.11it/s]
#
# Simulation cycles:  41%|████      | 41/100 [00:03<00:04, 12.04it/s]
#
# Simulation cycles:  43%|████▎     | 43/100 [00:03<00:04, 11.92it/s]
#
# Simulation cycles:  45%|████▌     | 45/100 [00:03<00:04, 11.83it/s]
#
# Simulation cycles:  47%|████▋     | 47/100 [00:04<00:04, 11.91it/s]
#
# Simulation cycles:  49%|████▉     | 49/100 [00:04<00:04, 12.02it/s]
#
# Simulation cycles:  51%|█████     | 51/100 [00:04<00:04, 12.11it/s]
#
# Simulation cycles:  53%|█████▎    | 53/100 [00:04<00:03, 11.93it/s]
#
# Simulation cycles:  55%|█████▌    | 55/100 [00:04<00:03, 11.81it/s]
#
# Simulation cycles:  57%|█████▋    | 57/100 [00:04<00:03, 11.81it/s]
#
# Simulation cycles:  59%|█████▉    | 59/100 [00:05<00:03, 11.44it/s]
#
# Simulation cycles:  61%|██████    | 61/100 [00:05<00:03, 11.69it/s]
#
# Simulation cycles:  63%|██████▎   | 63/100 [00:05<00:03, 11.68it/s]
#
# Simulation cycles:  65%|██████▌   | 65/100 [00:05<00:02, 11.70it/s]
#
# Simulation cycles:  67%|██████▋   | 67/100 [00:05<00:02, 11.96it/s]
#
# Simulation cycles:  69%|██████▉   | 69/100 [00:05<00:02, 11.83it/s]
#
# Simulation cycles:  71%|███████   | 71/100 [00:06<00:02, 12.09it/s]
#
# Simulation cycles:  73%|███████▎  | 73/100 [00:06<00:02, 11.98it/s]
#
# Simulation cycles:  75%|███████▌  | 75/100 [00:06<00:02, 12.22it/s]
#
# Simulation cycles:  77%|███████▋  | 77/100 [00:06<00:01, 11.91it/s]
#
# Simulation cycles:  79%|███████▉  | 79/100 [00:06<00:01, 11.80it/s]
#
# Simulation cycles:  81%|████████  | 81/100 [00:06<00:01, 12.02it/s]
#
# Simulation cycles:  83%|████████▎ | 83/100 [00:07<00:01, 12.02it/s]
#
# Simulation cycles:  85%|████████▌ | 85/100 [00:07<00:01, 11.91it/s]
#
# Simulation cycles:  87%|████████▋ | 87/100 [00:07<00:01, 11.92it/s]
#
# Simulation cycles:  89%|████████▉ | 89/100 [00:07<00:00, 12.04it/s]
#
# Simulation cycles:  91%|█████████ | 91/100 [00:07<00:00, 11.55it/s]
#
# Simulation cycles:  93%|█████████▎| 93/100 [00:07<00:00, 11.83it/s]
#
# Simulation cycles:  95%|█████████▌| 95/100 [00:08<00:00, 11.76it/s]
#
# Simulation cycles:  97%|█████████▋| 97/100 [00:08<00:00, 11.76it/s]
#
# Simulation cycles:  99%|█████████▉| 99/100 [00:08<00:00, 11.79it/s]
#
#
# Variables in Matrix_MX_all:  25%|██▌       | 3/12 [00:36<01:49, 12.14s/it]
#
# Simulation cycles:   0%|          | 0/100 [00:00<?, ?it/s]
#
# Simulation cycles:   1%|          | 1/100 [00:00<00:39,  2.54it/s]
#
# Simulation cycles:   2%|▏         | 2/100 [00:00<00:34,  2.86it/s]
#
# Simulation cycles:   3%|▎         | 3/100 [00:00<00:29,  3.25it/s]
#
# Simulation cycles:   4%|▍         | 4/100 [00:01<00:27,  3.44it/s]
#
# Simulation cycles:   5%|▌         | 5/100 [00:01<00:27,  3.46it/s]
#
# Simulation cycles:   6%|▌         | 6/100 [00:01<00:28,  3.32it/s]
#
# Simulation cycles:   7%|▋         | 7/100 [00:02<00:31,  3.00it/s]
#
# Simulation cycles:   8%|▊         | 8/100 [00:02<00:30,  3.05it/s]
#
# Simulation cycles:   9%|▉         | 9/100 [00:02<00:29,  3.07it/s]
#
# Simulation cycles:  10%|█         | 10/100 [00:03<00:28,  3.14it/s]
#
# Simulation cycles:  11%|█         | 11/100 [00:03<00:27,  3.22it/s]
#
# Simulation cycles:  12%|█▏        | 12/100 [00:03<00:26,  3.30it/s]
#
# Simulation cycles:  13%|█▎        | 13/100 [00:04<00:26,  3.31it/s]
#
# Simulation cycles:  14%|█▍        | 14/100 [00:04<00:27,  3.11it/s]
#
# Simulation cycles:  15%|█▌        | 15/100 [00:04<00:27,  3.14it/s]
#
# Simulation cycles:  16%|█▌        | 16/100 [00:05<00:27,  3.01it/s]
#
# Simulation cycles:  17%|█▋        | 17/100 [00:05<00:26,  3.11it/s]
#
# Simulation cycles:  18%|█▊        | 18/100 [00:05<00:25,  3.26it/s]
#
# Simulation cycles:  19%|█▉        | 19/100 [00:05<00:24,  3.31it/s]
#
# Simulation cycles:  20%|██        | 20/100 [00:06<00:24,  3.23it/s]
#
# Simulation cycles:  21%|██        | 21/100 [00:06<00:24,  3.24it/s]
#
# Simulation cycles:  22%|██▏       | 22/100 [00:06<00:24,  3.24it/s]
#
# Simulation cycles:  23%|██▎       | 23/100 [00:07<00:23,  3.29it/s]
#
# Simulation cycles:  24%|██▍       | 24/100 [00:07<00:22,  3.35it/s]
#
# Simulation cycles:  25%|██▌       | 25/100 [00:07<00:22,  3.40it/s]
#
# Simulation cycles:  26%|██▌       | 26/100 [00:08<00:22,  3.35it/s]
#
# Simulation cycles:  27%|██▋       | 27/100 [00:08<00:21,  3.44it/s]
#
# Simulation cycles:  28%|██▊       | 28/100 [00:08<00:20,  3.49it/s]
#
# Simulation cycles:  29%|██▉       | 29/100 [00:08<00:20,  3.52it/s]
#
# Simulation cycles:  30%|███       | 30/100 [00:09<00:19,  3.55it/s]
#
# Simulation cycles:  31%|███       | 31/100 [00:09<00:19,  3.51it/s]
#
# Simulation cycles:  32%|███▏      | 32/100 [00:09<00:19,  3.46it/s]
#
# Simulation cycles:  33%|███▎      | 33/100 [00:10<00:19,  3.40it/s]
#
# Simulation cycles:  34%|███▍      | 34/100 [00:10<00:19,  3.40it/s]
#
# Simulation cycles:  35%|███▌      | 35/100 [00:10<00:19,  3.37it/s]
#
# Simulation cycles:  36%|███▌      | 36/100 [00:10<00:18,  3.37it/s]
#
# Simulation cycles:  37%|███▋      | 37/100 [00:11<00:18,  3.39it/s]
#
# Simulation cycles:  38%|███▊      | 38/100 [00:11<00:18,  3.42it/s]
#
# Simulation cycles:  39%|███▉      | 39/100 [00:11<00:17,  3.39it/s]
#
# Simulation cycles:  40%|████      | 40/100 [00:12<00:17,  3.35it/s]
#
# Simulation cycles:  41%|████      | 41/100 [00:12<00:17,  3.33it/s]
#
# Simulation cycles:  42%|████▏     | 42/100 [00:12<00:17,  3.26it/s]
#
# Simulation cycles:  43%|████▎     | 43/100 [00:13<00:17,  3.26it/s]
#
# Simulation cycles:  44%|████▍     | 44/100 [00:13<00:16,  3.30it/s]
#
# Simulation cycles:  45%|████▌     | 45/100 [00:13<00:16,  3.37it/s]
#
# Simulation cycles:  46%|████▌     | 46/100 [00:13<00:15,  3.38it/s]
#
# Simulation cycles:  47%|████▋     | 47/100 [00:14<00:16,  3.31it/s]
#
# Simulation cycles:  48%|████▊     | 48/100 [00:14<00:15,  3.37it/s]
#
# Simulation cycles:  49%|████▉     | 49/100 [00:14<00:15,  3.36it/s]
#
# Simulation cycles:  50%|█████     | 50/100 [00:15<00:14,  3.37it/s]
#
# Simulation cycles:  51%|█████     | 51/100 [00:15<00:14,  3.37it/s]
#
# Simulation cycles:  52%|█████▏    | 52/100 [00:15<00:14,  3.41it/s]
#
# Simulation cycles:  53%|█████▎    | 53/100 [00:16<00:14,  3.20it/s]
#
# Simulation cycles:  54%|█████▍    | 54/100 [00:16<00:15,  2.91it/s]
#
# Simulation cycles:  55%|█████▌    | 55/100 [00:16<00:15,  2.93it/s]
#
# Simulation cycles:  56%|█████▌    | 56/100 [00:17<00:14,  3.01it/s]
#
# Simulation cycles:  57%|█████▋    | 57/100 [00:17<00:14,  2.93it/s]
#
# Simulation cycles:  58%|█████▊    | 58/100 [00:17<00:14,  2.90it/s]
#
# Simulation cycles:  59%|█████▉    | 59/100 [00:18<00:14,  2.85it/s]
#
# Simulation cycles:  60%|██████    | 60/100 [00:18<00:14,  2.83it/s]
#
# Simulation cycles:  61%|██████    | 61/100 [00:18<00:13,  2.95it/s]
#
# Simulation cycles:  62%|██████▏   | 62/100 [00:19<00:12,  3.07it/s]
#
# Simulation cycles:  63%|██████▎   | 63/100 [00:19<00:11,  3.14it/s]
#
# Simulation cycles:  64%|██████▍   | 64/100 [00:19<00:12,  2.97it/s]
#
# Simulation cycles:  65%|██████▌   | 65/100 [00:20<00:11,  3.12it/s]
#
# Simulation cycles:  66%|██████▌   | 66/100 [00:20<00:11,  3.03it/s]
#
# Simulation cycles:  67%|██████▋   | 67/100 [00:20<00:11,  2.82it/s]
#
# Simulation cycles:  68%|██████▊   | 68/100 [00:21<00:11,  2.85it/s]
#
# Simulation cycles:  69%|██████▉   | 69/100 [00:21<00:10,  2.96it/s]
#
# Simulation cycles:  70%|███████   | 70/100 [00:21<00:10,  2.93it/s]
#
# Simulation cycles:  71%|███████   | 71/100 [00:22<00:09,  3.06it/s]
#
# Simulation cycles:  72%|███████▏  | 72/100 [00:22<00:08,  3.16it/s]
#
# Simulation cycles:  73%|███████▎  | 73/100 [00:22<00:08,  3.21it/s]
#
# Simulation cycles:  74%|███████▍  | 74/100 [00:23<00:08,  3.22it/s]
#
# Simulation cycles:  75%|███████▌  | 75/100 [00:23<00:07,  3.19it/s]
#
# Simulation cycles:  76%|███████▌  | 76/100 [00:23<00:07,  3.17it/s]
#
# Simulation cycles:  77%|███████▋  | 77/100 [00:24<00:07,  3.02it/s]
#
# Simulation cycles:  78%|███████▊  | 78/100 [00:24<00:07,  3.10it/s]
#
# Simulation cycles:  79%|███████▉  | 79/100 [00:24<00:06,  3.16it/s]
#
# Simulation cycles:  80%|████████  | 80/100 [00:25<00:06,  3.17it/s]
#
# Simulation cycles:  81%|████████  | 81/100 [00:25<00:06,  3.13it/s]
#
# Simulation cycles:  82%|████████▏ | 82/100 [00:25<00:05,  3.16it/s]
#
# Simulation cycles:  83%|████████▎ | 83/100 [00:25<00:05,  3.16it/s]
#
# Simulation cycles:  84%|████████▍ | 84/100 [00:26<00:04,  3.21it/s]
#
# Simulation cycles:  85%|████████▌ | 85/100 [00:26<00:04,  3.24it/s]
#
# Simulation cycles:  86%|████████▌ | 86/100 [00:26<00:04,  3.23it/s]
#
# Simulation cycles:  87%|████████▋ | 87/100 [00:27<00:04,  3.20it/s]
#
# Simulation cycles:  88%|████████▊ | 88/100 [00:27<00:03,  3.33it/s]
#
# Simulation cycles:  89%|████████▉ | 89/100 [00:27<00:03,  3.27it/s]
#
# Simulation cycles:  90%|█████████ | 90/100 [00:28<00:03,  3.14it/s]
#
# Simulation cycles:  91%|█████████ | 91/100 [00:28<00:02,  3.23it/s]
#
# Simulation cycles:  92%|█████████▏| 92/100 [00:28<00:02,  3.21it/s]
#
# Simulation cycles:  93%|█████████▎| 93/100 [00:29<00:02,  3.15it/s]
#
# Simulation cycles:  94%|█████████▍| 94/100 [00:29<00:01,  3.21it/s]
#
# Simulation cycles:  95%|█████████▌| 95/100 [00:29<00:01,  3.21it/s]
#
# Simulation cycles:  96%|█████████▌| 96/100 [00:30<00:01,  3.18it/s]
#
# Simulation cycles:  97%|█████████▋| 97/100 [00:30<00:00,  3.11it/s]
#
# Simulation cycles:  98%|█████████▊| 98/100 [00:30<00:00,  3.09it/s]
#
# Simulation cycles:  99%|█████████▉| 99/100 [00:31<00:00,  2.99it/s]
#
# Simulation cycles: 100%|██████████| 100/100 [00:31<00:00,  3.03it/s]
#
#
# Variables in Matrix_MX_all:  33%|███▎      | 4/12 [01:08<02:37, 19.74s/it]
#
# Simulation cycles:   0%|          | 0/100 [00:00<?, ?it/s]
#
# Simulation cycles:   1%|          | 1/100 [00:00<00:23,  4.14it/s]
#
# Simulation cycles:   2%|▏         | 2/100 [00:00<00:21,  4.51it/s]
#
# Simulation cycles:   3%|▎         | 3/100 [00:00<00:22,  4.36it/s]
#
# Simulation cycles:   4%|▍         | 4/100 [00:00<00:23,  4.13it/s]
#
# Simulation cycles:   5%|▌         | 5/100 [00:01<00:23,  4.05it/s]
#
# Simulation cycles:   6%|▌         | 6/100 [00:01<00:21,  4.42it/s]
#
# Simulation cycles:   7%|▋         | 7/100 [00:01<00:20,  4.50it/s]
#
# Simulation cycles:   8%|▊         | 8/100 [00:01<00:19,  4.67it/s]
#
# Simulation cycles:   9%|▉         | 9/100 [00:02<00:19,  4.72it/s]
#
# Simulation cycles:  10%|█         | 10/100 [00:02<00:18,  4.83it/s]
#
# Simulation cycles:  11%|█         | 11/100 [00:02<00:18,  4.85it/s]
#
# Simulation cycles:  12%|█▏        | 12/100 [00:02<00:18,  4.87it/s]
#
# Simulation cycles:  13%|█▎        | 13/100 [00:02<00:17,  4.93it/s]
#
# Simulation cycles:  14%|█▍        | 14/100 [00:03<00:17,  4.91it/s]
#
# Simulation cycles:  15%|█▌        | 15/100 [00:03<00:17,  4.93it/s]
#
# Simulation cycles:  16%|█▌        | 16/100 [00:03<00:16,  4.98it/s]
#
# Simulation cycles:  17%|█▋        | 17/100 [00:03<00:16,  4.91it/s]
#
# Simulation cycles:  18%|█▊        | 18/100 [00:03<00:16,  4.92it/s]
#
# Simulation cycles:  19%|█▉        | 19/100 [00:04<00:16,  5.00it/s]
#
# Simulation cycles:  20%|██        | 20/100 [00:04<00:15,  5.01it/s]
#
# Simulation cycles:  21%|██        | 21/100 [00:04<00:15,  5.00it/s]
#
# Simulation cycles:  22%|██▏       | 22/100 [00:04<00:15,  4.96it/s]
#
# Simulation cycles:  23%|██▎       | 23/100 [00:04<00:15,  4.96it/s]
#
# Simulation cycles:  24%|██▍       | 24/100 [00:05<00:15,  4.95it/s]
#
# Simulation cycles:  25%|██▌       | 25/100 [00:05<00:16,  4.58it/s]
#
# Simulation cycles:  26%|██▌       | 26/100 [00:05<00:15,  4.75it/s]
#
# Simulation cycles:  27%|██▋       | 27/100 [00:05<00:15,  4.65it/s]
#
# Simulation cycles:  28%|██▊       | 28/100 [00:05<00:15,  4.62it/s]
#
# Simulation cycles:  29%|██▉       | 29/100 [00:06<00:14,  4.74it/s]
#
# Simulation cycles:  30%|███       | 30/100 [00:06<00:14,  4.73it/s]
#
# Simulation cycles:  31%|███       | 31/100 [00:06<00:17,  3.99it/s]
#
# Simulation cycles:  32%|███▏      | 32/100 [00:06<00:17,  3.94it/s]
#
# Simulation cycles:  33%|███▎      | 33/100 [00:07<00:17,  3.86it/s]
#
# Simulation cycles:  34%|███▍      | 34/100 [00:07<00:20,  3.26it/s]
#
# Simulation cycles:  35%|███▌      | 35/100 [00:08<00:22,  2.87it/s]
#
# Simulation cycles:  36%|███▌      | 36/100 [00:08<00:19,  3.22it/s]
#
# Simulation cycles:  37%|███▋      | 37/100 [00:08<00:17,  3.57it/s]
#
# Simulation cycles:  38%|███▊      | 38/100 [00:08<00:15,  3.90it/s]
#
# Simulation cycles:  39%|███▉      | 39/100 [00:08<00:16,  3.75it/s]
#
# Simulation cycles:  40%|████      | 40/100 [00:09<00:15,  3.85it/s]
#
# Simulation cycles:  41%|████      | 41/100 [00:09<00:15,  3.78it/s]
#
# Simulation cycles:  42%|████▏     | 42/100 [00:09<00:14,  3.99it/s]
#
# Simulation cycles:  43%|████▎     | 43/100 [00:09<00:13,  4.19it/s]
#
# Simulation cycles:  44%|████▍     | 44/100 [00:10<00:13,  4.04it/s]
#
# Simulation cycles:  45%|████▌     | 45/100 [00:10<00:12,  4.27it/s]
#
# Simulation cycles:  46%|████▌     | 46/100 [00:10<00:12,  4.30it/s]
#
# Simulation cycles:  47%|████▋     | 47/100 [00:10<00:11,  4.50it/s]
#
# Simulation cycles:  48%|████▊     | 48/100 [00:11<00:11,  4.68it/s]
#
# Simulation cycles:  49%|████▉     | 49/100 [00:11<00:10,  4.66it/s]
#
# Simulation cycles:  50%|█████     | 50/100 [00:11<00:10,  4.69it/s]
#
# Simulation cycles:  51%|█████     | 51/100 [00:11<00:10,  4.67it/s]
#
# Simulation cycles:  52%|█████▏    | 52/100 [00:11<00:10,  4.50it/s]
#
# Simulation cycles:  53%|█████▎    | 53/100 [00:12<00:10,  4.42it/s]
#
# Simulation cycles:  54%|█████▍    | 54/100 [00:12<00:10,  4.28it/s]
#
# Simulation cycles:  55%|█████▌    | 55/100 [00:12<00:10,  4.28it/s]
#
# Simulation cycles:  56%|█████▌    | 56/100 [00:12<00:09,  4.41it/s]
#
# Simulation cycles:  57%|█████▋    | 57/100 [00:13<00:09,  4.59it/s]
#
# Simulation cycles:  58%|█████▊    | 58/100 [00:13<00:08,  4.69it/s]
#
# Simulation cycles:  59%|█████▉    | 59/100 [00:13<00:08,  4.85it/s]
#
# Simulation cycles:  60%|██████    | 60/100 [00:13<00:08,  4.63it/s]
#
# Simulation cycles:  61%|██████    | 61/100 [00:13<00:08,  4.73it/s]
#
# Simulation cycles:  62%|██████▏   | 62/100 [00:14<00:07,  4.85it/s]
#
# Simulation cycles:  63%|██████▎   | 63/100 [00:14<00:07,  4.86it/s]
#
# Simulation cycles:  64%|██████▍   | 64/100 [00:14<00:07,  4.70it/s]
#
# Simulation cycles:  65%|██████▌   | 65/100 [00:14<00:07,  4.74it/s]
#
# Simulation cycles:  66%|██████▌   | 66/100 [00:14<00:07,  4.80it/s]
#
# Simulation cycles:  67%|██████▋   | 67/100 [00:15<00:06,  4.76it/s]
#
# Simulation cycles:  68%|██████▊   | 68/100 [00:15<00:06,  4.74it/s]
#
# Simulation cycles:  69%|██████▉   | 69/100 [00:15<00:06,  4.92it/s]
#
# Simulation cycles:  70%|███████   | 70/100 [00:15<00:06,  4.83it/s]
#
# Simulation cycles:  71%|███████   | 71/100 [00:16<00:06,  4.26it/s]
#
# Simulation cycles:  72%|███████▏  | 72/100 [00:16<00:06,  4.22it/s]
#
# Simulation cycles:  73%|███████▎  | 73/100 [00:16<00:07,  3.76it/s]
#
# Simulation cycles:  74%|███████▍  | 74/100 [00:17<00:08,  3.21it/s]
#
# Simulation cycles:  75%|███████▌  | 75/100 [00:17<00:07,  3.20it/s]
#
# Simulation cycles:  76%|███████▌  | 76/100 [00:17<00:07,  3.34it/s]
#
# Simulation cycles:  77%|███████▋  | 77/100 [00:17<00:06,  3.66it/s]
#
# Simulation cycles:  78%|███████▊  | 78/100 [00:18<00:05,  3.99it/s]
#
# Simulation cycles:  79%|███████▉  | 79/100 [00:18<00:04,  4.22it/s]
#
# Simulation cycles:  80%|████████  | 80/100 [00:18<00:04,  4.47it/s]
#
# Simulation cycles:  81%|████████  | 81/100 [00:18<00:04,  4.57it/s]
#
# Simulation cycles:  82%|████████▏ | 82/100 [00:18<00:03,  4.63it/s]
#
# Simulation cycles:  83%|████████▎ | 83/100 [00:19<00:04,  4.22it/s]
#
# Simulation cycles:  84%|████████▍ | 84/100 [00:19<00:03,  4.40it/s]
#
# Simulation cycles:  85%|████████▌ | 85/100 [00:19<00:03,  4.17it/s]
#
# Simulation cycles:  86%|████████▌ | 86/100 [00:19<00:03,  4.08it/s]
#
# Simulation cycles:  87%|████████▋ | 87/100 [00:20<00:03,  4.33it/s]
#
# Simulation cycles:  88%|████████▊ | 88/100 [00:20<00:02,  4.51it/s]
#
# Simulation cycles:  89%|████████▉ | 89/100 [00:20<00:02,  4.70it/s]
#
# Simulation cycles:  90%|█████████ | 90/100 [00:20<00:02,  4.65it/s]
#
# Simulation cycles:  91%|█████████ | 91/100 [00:20<00:01,  4.65it/s]
#
# Simulation cycles:  92%|█████████▏| 92/100 [00:21<00:01,  4.73it/s]
#
# Simulation cycles:  93%|█████████▎| 93/100 [00:21<00:01,  4.80it/s]
#
# Simulation cycles:  94%|█████████▍| 94/100 [00:21<00:01,  4.81it/s]
#
# Simulation cycles:  95%|█████████▌| 95/100 [00:21<00:01,  4.79it/s]
#
# Simulation cycles:  96%|█████████▌| 96/100 [00:21<00:00,  4.66it/s]
#
# Simulation cycles:  97%|█████████▋| 97/100 [00:22<00:00,  4.39it/s]
#
# Simulation cycles:  98%|█████████▊| 98/100 [00:22<00:00,  4.59it/s]
#
# Simulation cycles:  99%|█████████▉| 99/100 [00:22<00:00,  4.69it/s]
#
# Simulation cycles: 100%|██████████| 100/100 [00:22<00:00,  4.71it/s]
#
#
# Variables in Matrix_MX_all:  42%|████▏     | 5/12 [01:30<02:25, 20.85s/it]
#
# Simulation cycles:   0%|          | 0/100 [00:00<?, ?it/s]
#
# Simulation cycles:   1%|          | 1/100 [00:00<00:28,  3.53it/s]
#
# Simulation cycles:   2%|▏         | 2/100 [00:00<00:27,  3.63it/s]
#
# Simulation cycles:   3%|▎         | 3/100 [00:00<00:24,  3.96it/s]
#
# Simulation cycles:   4%|▍         | 4/100 [00:01<00:23,  4.09it/s]
#
# Simulation cycles:   5%|▌         | 5/100 [00:01<00:23,  4.09it/s]
#
# Simulation cycles:   6%|▌         | 6/100 [00:01<00:22,  4.15it/s]
#
# Simulation cycles:   7%|▋         | 7/100 [00:01<00:21,  4.25it/s]
#
# Simulation cycles:   8%|▊         | 8/100 [00:01<00:21,  4.25it/s]
#
# Simulation cycles:   9%|▉         | 9/100 [00:02<00:21,  4.29it/s]
#
# Simulation cycles:  10%|█         | 10/100 [00:02<00:21,  4.22it/s]
#
# Simulation cycles:  11%|█         | 11/100 [00:02<00:21,  4.17it/s]
#
# Simulation cycles:  12%|█▏        | 12/100 [00:02<00:20,  4.20it/s]
#
# Simulation cycles:  13%|█▎        | 13/100 [00:03<00:20,  4.24it/s]
#
# Simulation cycles:  14%|█▍        | 14/100 [00:03<00:20,  4.17it/s]
#
# Simulation cycles:  15%|█▌        | 15/100 [00:03<00:20,  4.16it/s]
#
# Simulation cycles:  16%|█▌        | 16/100 [00:03<00:20,  4.17it/s]
#
# Simulation cycles:  17%|█▋        | 17/100 [00:04<00:19,  4.25it/s]
#
# Simulation cycles:  18%|█▊        | 18/100 [00:04<00:18,  4.39it/s]
#
# Simulation cycles:  19%|█▉        | 19/100 [00:04<00:18,  4.32it/s]
#
# Simulation cycles:  20%|██        | 20/100 [00:04<00:18,  4.23it/s]
#
# Simulation cycles:  21%|██        | 21/100 [00:05<00:18,  4.25it/s]
#
# Simulation cycles:  22%|██▏       | 22/100 [00:05<00:18,  4.26it/s]
#
# Simulation cycles:  23%|██▎       | 23/100 [00:05<00:17,  4.33it/s]
#
# Simulation cycles:  24%|██▍       | 24/100 [00:05<00:17,  4.31it/s]
#
# Simulation cycles:  25%|██▌       | 25/100 [00:05<00:18,  4.14it/s]
#
# Simulation cycles:  26%|██▌       | 26/100 [00:06<00:17,  4.18it/s]
#
# Simulation cycles:  27%|██▋       | 27/100 [00:06<00:17,  4.26it/s]
#
# Simulation cycles:  28%|██▊       | 28/100 [00:06<00:17,  4.23it/s]
#
# Simulation cycles:  29%|██▉       | 29/100 [00:06<00:16,  4.22it/s]
#
# Simulation cycles:  30%|███       | 30/100 [00:07<00:16,  4.23it/s]
#
# Simulation cycles:  31%|███       | 31/100 [00:07<00:16,  4.18it/s]
#
# Simulation cycles:  32%|███▏      | 32/100 [00:07<00:16,  4.14it/s]
#
# Simulation cycles:  33%|███▎      | 33/100 [00:07<00:15,  4.27it/s]
#
# Simulation cycles:  34%|███▍      | 34/100 [00:08<00:15,  4.22it/s]
#
# Simulation cycles:  35%|███▌      | 35/100 [00:08<00:15,  4.25it/s]
#
# Simulation cycles:  36%|███▌      | 36/100 [00:08<00:15,  4.12it/s]
#
# Simulation cycles:  37%|███▋      | 37/100 [00:08<00:14,  4.20it/s]
#
# Simulation cycles:  38%|███▊      | 38/100 [00:09<00:14,  4.15it/s]
#
# Simulation cycles:  39%|███▉      | 39/100 [00:09<00:14,  4.18it/s]
#
# Simulation cycles:  40%|████      | 40/100 [00:09<00:14,  4.19it/s]
#
# Simulation cycles:  41%|████      | 41/100 [00:09<00:14,  3.94it/s]
#
# Simulation cycles:  42%|████▏     | 42/100 [00:10<00:15,  3.68it/s]
#
# Simulation cycles:  43%|████▎     | 43/100 [00:10<00:15,  3.57it/s]
#
# Simulation cycles:  44%|████▍     | 44/100 [00:10<00:14,  3.81it/s]
#
# Simulation cycles:  45%|████▌     | 45/100 [00:10<00:14,  3.90it/s]
#
# Simulation cycles:  46%|████▌     | 46/100 [00:11<00:13,  4.06it/s]
#
# Simulation cycles:  47%|████▋     | 47/100 [00:11<00:12,  4.15it/s]
#
# Simulation cycles:  48%|████▊     | 48/100 [00:11<00:12,  4.28it/s]
#
# Simulation cycles:  49%|████▉     | 49/100 [00:11<00:12,  4.18it/s]
#
# Simulation cycles:  50%|█████     | 50/100 [00:12<00:12,  4.07it/s]
#
# Simulation cycles:  51%|█████     | 51/100 [00:12<00:11,  4.09it/s]
#
# Simulation cycles:  52%|█████▏    | 52/100 [00:12<00:11,  4.11it/s]
#
# Simulation cycles:  53%|█████▎    | 53/100 [00:12<00:11,  4.10it/s]
#
# Simulation cycles:  54%|█████▍    | 54/100 [00:13<00:11,  4.01it/s]
#
# Simulation cycles:  55%|█████▌    | 55/100 [00:13<00:11,  4.08it/s]
#
# Simulation cycles:  56%|█████▌    | 56/100 [00:13<00:10,  4.14it/s]
#
# Simulation cycles:  57%|█████▋    | 57/100 [00:13<00:10,  4.23it/s]
#
# Simulation cycles:  58%|█████▊    | 58/100 [00:14<00:10,  4.19it/s]
#
# Simulation cycles:  59%|█████▉    | 59/100 [00:14<00:09,  4.21it/s]
#
# Simulation cycles:  60%|██████    | 60/100 [00:14<00:09,  4.29it/s]
#
# Simulation cycles:  61%|██████    | 61/100 [00:14<00:08,  4.40it/s]
#
# Simulation cycles:  62%|██████▏   | 62/100 [00:14<00:08,  4.47it/s]
#
# Simulation cycles:  63%|██████▎   | 63/100 [00:15<00:08,  4.49it/s]
#
# Simulation cycles:  64%|██████▍   | 64/100 [00:15<00:07,  4.54it/s]
#
# Simulation cycles:  65%|██████▌   | 65/100 [00:15<00:07,  4.42it/s]
#
# Simulation cycles:  66%|██████▌   | 66/100 [00:15<00:07,  4.35it/s]
#
# Simulation cycles:  67%|██████▋   | 67/100 [00:16<00:07,  4.35it/s]
#
# Simulation cycles:  68%|██████▊   | 68/100 [00:16<00:08,  3.99it/s]
#
# Simulation cycles:  69%|██████▉   | 69/100 [00:16<00:07,  4.07it/s]
#
# Simulation cycles:  70%|███████   | 70/100 [00:16<00:07,  4.11it/s]
#
# Simulation cycles:  71%|███████   | 71/100 [00:17<00:07,  4.09it/s]
#
# Simulation cycles:  72%|███████▏  | 72/100 [00:17<00:06,  4.12it/s]
#
# Simulation cycles:  73%|███████▎  | 73/100 [00:17<00:06,  4.09it/s]
#
# Simulation cycles:  74%|███████▍  | 74/100 [00:17<00:06,  4.22it/s]
#
# Simulation cycles:  75%|███████▌  | 75/100 [00:17<00:05,  4.30it/s]
#
# Simulation cycles:  76%|███████▌  | 76/100 [00:18<00:05,  4.26it/s]
#
# Simulation cycles:  77%|███████▋  | 77/100 [00:18<00:05,  4.21it/s]
#
# Simulation cycles:  78%|███████▊  | 78/100 [00:18<00:05,  4.21it/s]
#
# Simulation cycles:  79%|███████▉  | 79/100 [00:18<00:04,  4.32it/s]
#
# Simulation cycles:  80%|████████  | 80/100 [00:19<00:04,  4.23it/s]
#
# Simulation cycles:  81%|████████  | 81/100 [00:19<00:04,  4.11it/s]
#
# Simulation cycles:  82%|████████▏ | 82/100 [00:19<00:04,  4.12it/s]
#
# Simulation cycles:  83%|████████▎ | 83/100 [00:19<00:04,  3.95it/s]
#
# Simulation cycles:  84%|████████▍ | 84/100 [00:20<00:03,  4.02it/s]
#
# Simulation cycles:  85%|████████▌ | 85/100 [00:20<00:03,  4.07it/s]
#
# Simulation cycles:  86%|████████▌ | 86/100 [00:20<00:03,  4.10it/s]
#
# Simulation cycles:  87%|████████▋ | 87/100 [00:20<00:03,  4.10it/s]
#
# Simulation cycles:  88%|████████▊ | 88/100 [00:21<00:02,  4.11it/s]
#
# Simulation cycles:  89%|████████▉ | 89/100 [00:21<00:02,  4.19it/s]
#
# Simulation cycles:  90%|█████████ | 90/100 [00:21<00:02,  4.21it/s]
#
# Simulation cycles:  91%|█████████ | 91/100 [00:21<00:02,  4.19it/s]
#
# Simulation cycles:  92%|█████████▏| 92/100 [00:22<00:01,  4.26it/s]
#
# Simulation cycles:  93%|█████████▎| 93/100 [00:22<00:01,  4.36it/s]
#
# Simulation cycles:  94%|█████████▍| 94/100 [00:22<00:01,  4.43it/s]
#
# Simulation cycles:  95%|█████████▌| 95/100 [00:22<00:01,  4.36it/s]
#
# Simulation cycles:  96%|█████████▌| 96/100 [00:23<00:00,  4.25it/s]
#
# Simulation cycles:  97%|█████████▋| 97/100 [00:23<00:00,  3.89it/s]
#
# Simulation cycles:  98%|█████████▊| 98/100 [00:23<00:00,  3.82it/s]
#
# Simulation cycles:  99%|█████████▉| 99/100 [00:23<00:00,  3.80it/s]
#
# Simulation cycles: 100%|██████████| 100/100 [00:24<00:00,  3.73it/s]
#
#
# Variables in Matrix_MX_all:  50%|█████     | 6/12 [01:55<02:11, 21.96s/it]
#
# Simulation cycles:   0%|          | 0/100 [00:00<?, ?it/s]
#
# Simulation cycles:   1%|          | 1/100 [00:00<00:12,  7.75it/s]
#
# Simulation cycles:   2%|▏         | 2/100 [00:00<00:11,  8.24it/s]
#
# Simulation cycles:   3%|▎         | 3/100 [00:00<00:11,  8.13it/s]
#
# Simulation cycles:   4%|▍         | 4/100 [00:00<00:12,  7.89it/s]
#
# Simulation cycles:   5%|▌         | 5/100 [00:00<00:12,  7.84it/s]
#
# Simulation cycles:   6%|▌         | 6/100 [00:00<00:12,  7.58it/s]
#
# Simulation cycles:   7%|▋         | 7/100 [00:00<00:12,  7.71it/s]
#
# Simulation cycles:   8%|▊         | 8/100 [00:01<00:11,  7.78it/s]
#
# Simulation cycles:   9%|▉         | 9/100 [00:01<00:11,  7.77it/s]
#
# Simulation cycles:  10%|█         | 10/100 [00:01<00:11,  7.93it/s]
#
# Simulation cycles:  11%|█         | 11/100 [00:01<00:11,  7.87it/s]
#
# Simulation cycles:  12%|█▏        | 12/100 [00:01<00:10,  8.03it/s]
#
# Simulation cycles:  13%|█▎        | 13/100 [00:01<00:12,  7.10it/s]
#
# Simulation cycles:  14%|█▍        | 14/100 [00:01<00:12,  6.90it/s]
#
# Simulation cycles:  15%|█▌        | 15/100 [00:01<00:12,  6.99it/s]
#
# Simulation cycles:  16%|█▌        | 16/100 [00:02<00:12,  6.77it/s]
#
# Simulation cycles:  17%|█▋        | 17/100 [00:02<00:12,  6.78it/s]
#
# Simulation cycles:  18%|█▊        | 18/100 [00:02<00:11,  7.15it/s]
#
# Simulation cycles:  19%|█▉        | 19/100 [00:02<00:11,  7.36it/s]
#
# Simulation cycles:  20%|██        | 20/100 [00:02<00:10,  7.55it/s]
#
# Simulation cycles:  21%|██        | 21/100 [00:02<00:10,  7.48it/s]
#
# Simulation cycles:  22%|██▏       | 22/100 [00:02<00:10,  7.54it/s]
#
# Simulation cycles:  23%|██▎       | 23/100 [00:03<00:10,  7.58it/s]
#
# Simulation cycles:  24%|██▍       | 24/100 [00:03<00:10,  7.58it/s]
#
# Simulation cycles:  25%|██▌       | 25/100 [00:03<00:10,  7.29it/s]
#
# Simulation cycles:  26%|██▌       | 26/100 [00:03<00:10,  7.35it/s]
#
# Simulation cycles:  27%|██▋       | 27/100 [00:03<00:09,  7.37it/s]
#
# Simulation cycles:  28%|██▊       | 28/100 [00:03<00:10,  7.16it/s]
#
# Simulation cycles:  29%|██▉       | 29/100 [00:03<00:09,  7.15it/s]
#
# Simulation cycles:  30%|███       | 30/100 [00:04<00:09,  7.20it/s]
#
# Simulation cycles:  31%|███       | 31/100 [00:04<00:09,  7.36it/s]
#
# Simulation cycles:  32%|███▏      | 32/100 [00:04<00:08,  7.73it/s]
#
# Simulation cycles:  33%|███▎      | 33/100 [00:04<00:08,  7.87it/s]
#
# Simulation cycles:  34%|███▍      | 34/100 [00:04<00:08,  8.00it/s]
#
# Simulation cycles:  35%|███▌      | 35/100 [00:04<00:08,  8.11it/s]
#
# Simulation cycles:  36%|███▌      | 36/100 [00:04<00:07,  8.30it/s]
#
# Simulation cycles:  37%|███▋      | 37/100 [00:04<00:07,  8.11it/s]
#
# Simulation cycles:  38%|███▊      | 38/100 [00:05<00:07,  7.92it/s]
#
# Simulation cycles:  39%|███▉      | 39/100 [00:05<00:07,  7.98it/s]
#
# Simulation cycles:  40%|████      | 40/100 [00:05<00:07,  7.67it/s]
#
# Simulation cycles:  41%|████      | 41/100 [00:05<00:07,  7.65it/s]
#
# Simulation cycles:  42%|████▏     | 42/100 [00:05<00:07,  7.55it/s]
#
# Simulation cycles:  43%|████▎     | 43/100 [00:05<00:07,  7.46it/s]
#
# Simulation cycles:  44%|████▍     | 44/100 [00:05<00:07,  7.40it/s]
#
# Simulation cycles:  45%|████▌     | 45/100 [00:05<00:07,  7.22it/s]
#
# Simulation cycles:  46%|████▌     | 46/100 [00:06<00:07,  7.41it/s]
#
# Simulation cycles:  47%|████▋     | 47/100 [00:06<00:07,  7.45it/s]
#
# Simulation cycles:  48%|████▊     | 48/100 [00:06<00:06,  7.44it/s]
#
# Simulation cycles:  49%|████▉     | 49/100 [00:06<00:06,  7.36it/s]
#
# Simulation cycles:  50%|█████     | 50/100 [00:06<00:06,  7.49it/s]
#
# Simulation cycles:  51%|█████     | 51/100 [00:06<00:06,  7.48it/s]
#
# Simulation cycles:  52%|█████▏    | 52/100 [00:06<00:06,  7.69it/s]
#
# Simulation cycles:  53%|█████▎    | 53/100 [00:07<00:05,  7.86it/s]
#
# Simulation cycles:  54%|█████▍    | 54/100 [00:07<00:05,  8.00it/s]
#
# Simulation cycles:  55%|█████▌    | 55/100 [00:07<00:05,  8.06it/s]
#
# Simulation cycles:  56%|█████▌    | 56/100 [00:07<00:05,  8.11it/s]
#
# Simulation cycles:  57%|█████▋    | 57/100 [00:07<00:05,  8.20it/s]
#
# Simulation cycles:  58%|█████▊    | 58/100 [00:07<00:05,  8.05it/s]
#
# Simulation cycles:  59%|█████▉    | 59/100 [00:07<00:05,  8.18it/s]
#
# Simulation cycles:  60%|██████    | 60/100 [00:07<00:04,  8.30it/s]
#
# Simulation cycles:  61%|██████    | 61/100 [00:07<00:04,  8.39it/s]
#
# Simulation cycles:  62%|██████▏   | 62/100 [00:08<00:04,  8.48it/s]
#
# Simulation cycles:  63%|██████▎   | 63/100 [00:08<00:04,  8.36it/s]
#
# Simulation cycles:  64%|██████▍   | 64/100 [00:08<00:04,  8.42it/s]
#
# Simulation cycles:  65%|██████▌   | 65/100 [00:08<00:04,  8.47it/s]
#
# Simulation cycles:  66%|██████▌   | 66/100 [00:08<00:03,  8.55it/s]
#
# Simulation cycles:  67%|██████▋   | 67/100 [00:08<00:03,  8.29it/s]
#
# Simulation cycles:  68%|██████▊   | 68/100 [00:08<00:03,  8.33it/s]
#
# Simulation cycles:  69%|██████▉   | 69/100 [00:08<00:03,  8.21it/s]
#
# Simulation cycles:  70%|███████   | 70/100 [00:09<00:03,  8.30it/s]
#
# Simulation cycles:  71%|███████   | 71/100 [00:09<00:03,  8.38it/s]
#
# Simulation cycles:  72%|███████▏  | 72/100 [00:09<00:03,  8.32it/s]
#
# Simulation cycles:  73%|███████▎  | 73/100 [00:09<00:03,  8.42it/s]
#
# Simulation cycles:  74%|███████▍  | 74/100 [00:09<00:03,  8.36it/s]
#
# Simulation cycles:  75%|███████▌  | 75/100 [00:09<00:03,  8.11it/s]
#
# Simulation cycles:  76%|███████▌  | 76/100 [00:09<00:02,  8.10it/s]
#
# Simulation cycles:  77%|███████▋  | 77/100 [00:09<00:02,  8.25it/s]
#
# Simulation cycles:  78%|███████▊  | 78/100 [00:10<00:02,  8.33it/s]
#
# Simulation cycles:  79%|███████▉  | 79/100 [00:10<00:02,  8.31it/s]
#
# Simulation cycles:  80%|████████  | 80/100 [00:10<00:02,  8.34it/s]
#
# Simulation cycles:  81%|████████  | 81/100 [00:10<00:02,  8.26it/s]
#
# Simulation cycles:  82%|████████▏ | 82/100 [00:10<00:02,  8.40it/s]
#
# Simulation cycles:  83%|████████▎ | 83/100 [00:10<00:02,  8.28it/s]
#
# Simulation cycles:  84%|████████▍ | 84/100 [00:10<00:01,  8.15it/s]
#
# Simulation cycles:  85%|████████▌ | 85/100 [00:10<00:01,  8.26it/s]
#
# Simulation cycles:  86%|████████▌ | 86/100 [00:10<00:01,  8.30it/s]
#
# Simulation cycles:  87%|████████▋ | 87/100 [00:11<00:01,  8.23it/s]
#
# Simulation cycles:  88%|████████▊ | 88/100 [00:11<00:01,  8.22it/s]
#
# Simulation cycles:  89%|████████▉ | 89/100 [00:11<00:01,  8.12it/s]
#
# Simulation cycles:  90%|█████████ | 90/100 [00:11<00:01,  8.24it/s]
#
# Simulation cycles:  91%|█████████ | 91/100 [00:11<00:01,  8.19it/s]
#
# Simulation cycles:  92%|█████████▏| 92/100 [00:11<00:00,  8.26it/s]
#
# Simulation cycles:  93%|█████████▎| 93/100 [00:11<00:00,  8.19it/s]
#
# Simulation cycles:  94%|█████████▍| 94/100 [00:11<00:00,  8.32it/s]
#
# Simulation cycles:  95%|█████████▌| 95/100 [00:12<00:00,  8.33it/s]
#
# Simulation cycles:  96%|█████████▌| 96/100 [00:12<00:00,  8.36it/s]
#
# Simulation cycles:  97%|█████████▋| 97/100 [00:12<00:00,  8.37it/s]
#
# Simulation cycles:  98%|█████████▊| 98/100 [00:12<00:00,  8.30it/s]
#
# Simulation cycles:  99%|█████████▉| 99/100 [00:12<00:00,  8.18it/s]
#
# Simulation cycles: 100%|██████████| 100/100 [00:12<00:00,  8.11it/s]
#
#
# Variables in Matrix_MX_all:  58%|█████▊    | 7/12 [02:07<01:34, 18.94s/it]
#
# Simulation cycles:   0%|          | 0/100 [00:00<?, ?it/s]
#
# Simulation cycles:   1%|          | 1/100 [00:00<00:12,  7.79it/s]
#
# Simulation cycles:   2%|▏         | 2/100 [00:00<00:13,  7.46it/s]
#
# Simulation cycles:   3%|▎         | 3/100 [00:00<00:12,  7.51it/s]
#
# Simulation cycles:   4%|▍         | 4/100 [00:00<00:12,  7.68it/s]
#
# Simulation cycles:   5%|▌         | 5/100 [00:00<00:12,  7.53it/s]
#
# Simulation cycles:   6%|▌         | 6/100 [00:00<00:12,  7.64it/s]
#
# Simulation cycles:   7%|▋         | 7/100 [00:00<00:11,  7.78it/s]
#
# Simulation cycles:   8%|▊         | 8/100 [00:01<00:11,  7.67it/s]
#
# Simulation cycles:   9%|▉         | 9/100 [00:01<00:11,  7.79it/s]
#
# Simulation cycles:  10%|█         | 10/100 [00:01<00:11,  7.87it/s]
#
# Simulation cycles:  11%|█         | 11/100 [00:01<00:11,  7.83it/s]
#
# Simulation cycles:  12%|█▏        | 12/100 [00:01<00:11,  7.94it/s]
#
# Simulation cycles:  13%|█▎        | 13/100 [00:01<00:10,  8.08it/s]
#
# Simulation cycles:  14%|█▍        | 14/100 [00:01<00:10,  8.07it/s]
#
# Simulation cycles:  15%|█▌        | 15/100 [00:01<00:10,  7.99it/s]
#
# Simulation cycles:  16%|█▌        | 16/100 [00:02<00:10,  7.99it/s]
#
# Simulation cycles:  17%|█▋        | 17/100 [00:02<00:10,  8.02it/s]
#
# Simulation cycles:  18%|█▊        | 18/100 [00:02<00:10,  7.98it/s]
#
# Simulation cycles:  19%|█▉        | 19/100 [00:02<00:09,  8.12it/s]
#
# Simulation cycles:  20%|██        | 20/100 [00:02<00:09,  8.21it/s]
#
# Simulation cycles:  21%|██        | 21/100 [00:02<00:09,  8.19it/s]
#
# Simulation cycles:  22%|██▏       | 22/100 [00:02<00:09,  8.10it/s]
#
# Simulation cycles:  23%|██▎       | 23/100 [00:02<00:09,  7.82it/s]
#
# Simulation cycles:  24%|██▍       | 24/100 [00:03<00:09,  7.87it/s]
#
# Simulation cycles:  25%|██▌       | 25/100 [00:03<00:09,  7.92it/s]
#
# Simulation cycles:  26%|██▌       | 26/100 [00:03<00:09,  8.01it/s]
#
# Simulation cycles:  27%|██▋       | 27/100 [00:03<00:09,  8.02it/s]
#
# Simulation cycles:  28%|██▊       | 28/100 [00:03<00:08,  8.01it/s]
#
# Simulation cycles:  29%|██▉       | 29/100 [00:03<00:09,  7.83it/s]
#
# Simulation cycles:  30%|███       | 30/100 [00:03<00:08,  7.79it/s]
#
# Simulation cycles:  31%|███       | 31/100 [00:03<00:08,  8.03it/s]
#
# Simulation cycles:  32%|███▏      | 32/100 [00:04<00:08,  7.97it/s]
#
# Simulation cycles:  33%|███▎      | 33/100 [00:04<00:08,  7.85it/s]
#
# Simulation cycles:  34%|███▍      | 34/100 [00:04<00:08,  7.75it/s]
#
# Simulation cycles:  35%|███▌      | 35/100 [00:04<00:08,  7.84it/s]
#
# Simulation cycles:  36%|███▌      | 36/100 [00:04<00:08,  7.79it/s]
#
# Simulation cycles:  37%|███▋      | 37/100 [00:04<00:08,  7.83it/s]
#
# Simulation cycles:  38%|███▊      | 38/100 [00:04<00:08,  7.71it/s]
#
# Simulation cycles:  39%|███▉      | 39/100 [00:04<00:07,  7.64it/s]
#
# Simulation cycles:  40%|████      | 40/100 [00:05<00:08,  7.36it/s]
#
# Simulation cycles:  41%|████      | 41/100 [00:05<00:08,  7.18it/s]
#
# Simulation cycles:  42%|████▏     | 42/100 [00:05<00:08,  6.95it/s]
#
# Simulation cycles:  43%|████▎     | 43/100 [00:05<00:08,  6.98it/s]
#
# Simulation cycles:  44%|████▍     | 44/100 [00:05<00:07,  7.13it/s]
#
# Simulation cycles:  45%|████▌     | 45/100 [00:05<00:07,  7.27it/s]
#
# Simulation cycles:  46%|████▌     | 46/100 [00:05<00:07,  7.12it/s]
#
# Simulation cycles:  47%|████▋     | 47/100 [00:06<00:07,  7.09it/s]
#
# Simulation cycles:  48%|████▊     | 48/100 [00:06<00:07,  7.18it/s]
#
# Simulation cycles:  49%|████▉     | 49/100 [00:06<00:07,  7.04it/s]
#
# Simulation cycles:  50%|█████     | 50/100 [00:06<00:07,  7.00it/s]
#
# Simulation cycles:  51%|█████     | 51/100 [00:06<00:06,  7.05it/s]
#
# Simulation cycles:  52%|█████▏    | 52/100 [00:06<00:07,  6.41it/s]
#
# Simulation cycles:  53%|█████▎    | 53/100 [00:07<00:07,  6.24it/s]
#
# Simulation cycles:  54%|█████▍    | 54/100 [00:07<00:07,  5.91it/s]
#
# Simulation cycles:  55%|█████▌    | 55/100 [00:07<00:07,  6.11it/s]
#
# Simulation cycles:  56%|█████▌    | 56/100 [00:07<00:06,  6.54it/s]
#
# Simulation cycles:  57%|█████▋    | 57/100 [00:07<00:06,  6.91it/s]
#
# Simulation cycles:  58%|█████▊    | 58/100 [00:07<00:05,  7.16it/s]
#
# Simulation cycles:  59%|█████▉    | 59/100 [00:07<00:05,  7.41it/s]
#
# Simulation cycles:  60%|██████    | 60/100 [00:08<00:05,  7.56it/s]
#
# Simulation cycles:  61%|██████    | 61/100 [00:08<00:05,  7.39it/s]
#
# Simulation cycles:  62%|██████▏   | 62/100 [00:08<00:05,  7.36it/s]
#
# Simulation cycles:  63%|██████▎   | 63/100 [00:08<00:05,  6.70it/s]
#
# Simulation cycles:  64%|██████▍   | 64/100 [00:08<00:05,  6.88it/s]
#
# Simulation cycles:  65%|██████▌   | 65/100 [00:08<00:05,  6.89it/s]
#
# Simulation cycles:  66%|██████▌   | 66/100 [00:08<00:04,  6.89it/s]
#
# Simulation cycles:  67%|██████▋   | 67/100 [00:09<00:04,  6.89it/s]
#
# Simulation cycles:  68%|██████▊   | 68/100 [00:09<00:04,  6.74it/s]
#
# Simulation cycles:  69%|██████▉   | 69/100 [00:09<00:04,  6.24it/s]
#
# Simulation cycles:  70%|███████   | 70/100 [00:09<00:04,  6.22it/s]
#
# Simulation cycles:  71%|███████   | 71/100 [00:09<00:04,  6.46it/s]
#
# Simulation cycles:  72%|███████▏  | 72/100 [00:09<00:04,  6.68it/s]
#
# ...
#
# Simulation cycles:  46%|████▌     | 46/100 [15:12<17:52, 19.86s/it]
#
# Simulation cycles:  47%|████▋     | 47/100 [15:32<17:31, 19.85s/it]
#
# Simulation cycles:  48%|████▊     | 48/100 [15:51<17:05, 19.72s/it]
#
# Simulation cycles:  49%|████▉     | 49/100 [16:11<16:49, 19.80s/it]
#
# Simulation cycles:  50%|█████     | 50/100 [16:31<16:28, 19.78s/it]
#
# Simulation cycles:  51%|█████     | 51/100 [16:50<16:09, 19.79s/it]
#
# Simulation cycles:  52%|█████▏    | 52/100 [17:10<15:49, 19.78s/it]
#
# Simulation cycles:  53%|█████▎    | 53/100 [17:30<15:33, 19.87s/it]
#
# Simulation cycles:  54%|█████▍    | 54/100 [17:50<15:14, 19.88s/it]
#
# Simulation cycles:  55%|█████▌    | 55/100 [18:10<14:54, 19.88s/it]
#
# Simulation cycles:  56%|█████▌    | 56/100 [18:30<14:32, 19.82s/it]
#
# Simulation cycles:  57%|█████▋    | 57/100 [18:50<14:16, 19.92s/it]
#
# Simulation cycles:  58%|█████▊    | 58/100 [19:10<13:55, 19.90s/it]
#
# Simulation cycles:  59%|█████▉    | 59/100 [19:30<13:35, 19.89s/it]
#
# Simulation cycles:  60%|██████    | 60/100 [19:49<13:15, 19.88s/it]
#
# Simulation cycles:  61%|██████    | 61/100 [20:10<13:00, 20.02s/it]
#
# Simulation cycles:  62%|██████▏   | 62/100 [20:29<12:36, 19.90s/it]
#
# Simulation cycles:  63%|██████▎   | 63/100 [20:49<12:17, 19.93s/it]
#
# Simulation cycles:  64%|██████▍   | 64/100 [21:09<11:51, 19.76s/it]
#
# Simulation cycles:  65%|██████▌   | 65/100 [21:29<11:35, 19.88s/it]
#
# Simulation cycles:  66%|██████▌   | 66/100 [21:48<11:11, 19.76s/it]
#
# Simulation cycles:  67%|██████▋   | 67/100 [22:08<10:54, 19.82s/it]
#
# Simulation cycles:  68%|██████▊   | 68/100 [22:28<10:34, 19.82s/it]
#
# Simulation cycles:  69%|██████▉   | 69/100 [22:48<10:12, 19.76s/it]
#
# Simulation cycles:  70%|███████   | 70/100 [23:08<09:53, 19.79s/it]
#
# Simulation cycles:  71%|███████   | 71/100 [23:27<09:33, 19.79s/it]
#
# Simulation cycles:  72%|███████▏  | 72/100 [23:47<09:14, 19.81s/it]
#
# Simulation cycles:  73%|███████▎  | 73/100 [24:07<08:57, 19.89s/it]
#
# Simulation cycles:  74%|███████▍  | 74/100 [24:27<08:37, 19.91s/it]
#
# Simulation cycles:  75%|███████▌  | 75/100 [24:47<08:15, 19.83s/it]
#
# Simulation cycles:  76%|███████▌  | 76/100 [25:07<07:56, 19.87s/it]
#
# Simulation cycles:  77%|███████▋  | 77/100 [25:27<07:38, 19.93s/it]
#
# Simulation cycles:  78%|███████▊  | 78/100 [25:47<07:17, 19.91s/it]
#
# Simulation cycles:  79%|███████▉  | 79/100 [26:07<06:57, 19.88s/it]
#
# Simulation cycles:  80%|████████  | 80/100 [26:26<06:36, 19.83s/it]
#
# Simulation cycles:  81%|████████  | 81/100 [26:47<06:18, 19.90s/it]
#
# Simulation cycles:  82%|████████▏ | 82/100 [27:06<05:56, 19.82s/it]
#
# Simulation cycles:  83%|████████▎ | 83/100 [27:26<05:37, 19.88s/it]
#
# Simulation cycles:  84%|████████▍ | 84/100 [27:46<05:19, 19.94s/it]
#
# Simulation cycles:  85%|████████▌ | 85/100 [28:06<04:59, 19.95s/it]
#
# Simulation cycles:  86%|████████▌ | 86/100 [28:26<04:38, 19.93s/it]
#
# Simulation cycles:  87%|████████▋ | 87/100 [28:46<04:18, 19.87s/it]
#
# Simulation cycles:  88%|████████▊ | 88/100 [29:05<03:57, 19.80s/it]
#
# Simulation cycles:  89%|████████▉ | 89/100 [29:25<03:37, 19.82s/it]
#
# Simulation cycles:  90%|█████████ | 90/100 [29:45<03:18, 19.83s/it]
#
# Simulation cycles:  91%|█████████ | 91/100 [30:06<03:00, 20.00s/it]
#
# Simulation cycles:  92%|█████████▏| 92/100 [30:25<02:39, 19.94s/it]
#
# Simulation cycles:  93%|█████████▎| 93/100 [30:45<02:18, 19.84s/it]
#
# Simulation cycles:  94%|█████████▍| 94/100 [31:05<01:58, 19.80s/it]
#
# Simulation cycles:  95%|█████████▌| 95/100 [31:24<01:38, 19.78s/it]
#
# Simulation cycles:  96%|█████████▌| 96/100 [31:44<01:18, 19.73s/it]
#
# Simulation cycles:  97%|█████████▋| 97/100 [32:04<00:59, 19.75s/it]
#
# Simulation cycles:  98%|█████████▊| 98/100 [32:24<00:39, 19.83s/it]
#
# Simulation cycles:  99%|█████████▉| 99/100 [32:44<00:19, 19.88s/it]
#
# Simulation cycles: 100%|██████████| 100/100 [33:04<00:00, 19.81s/it]
#
#
# Variables in Matrix_GEN_M0_all:  25%|██▌       | 3/12 [2:00:24<5:58:27, 2389.70s/it]
#
# Simulation cycles:   0%|          | 0/100 [00:00<?, ?it/s]
#
# Simulation cycles:   1%|          | 1/100 [00:43<1:12:32, 43.97s/it]
#
# Simulation cycles:   2%|▏         | 2/100 [01:28<1:12:10, 44.19s/it]
#
# Simulation cycles:   3%|▎         | 3/100 [02:12<1:11:06, 43.98s/it]
#
# Simulation cycles:   4%|▍         | 4/100 [02:55<1:10:08, 43.84s/it]
#
# Simulation cycles:   5%|▌         | 5/100 [03:40<1:09:46, 44.07s/it]
#
# Simulation cycles:   6%|▌         | 6/100 [04:23<1:08:49, 43.93s/it]
#
# Simulation cycles:   7%|▋         | 7/100 [05:07<1:08:02, 43.90s/it]
#
# Simulation cycles:   8%|▊         | 8/100 [05:51<1:07:15, 43.87s/it]
#
# Simulation cycles:   9%|▉         | 9/100 [06:35<1:06:33, 43.89s/it]
#
# Simulation cycles:  10%|█         | 10/100 [07:19<1:06:08, 44.09s/it]
#
# Simulation cycles:  11%|█         | 11/100 [08:05<1:06:09, 44.60s/it]
#
# Simulation cycles:  12%|█▏        | 12/100 [08:49<1:05:12, 44.46s/it]
#
# Simulation cycles:  13%|█▎        | 13/100 [09:34<1:04:32, 44.51s/it]
#
# Simulation cycles:  14%|█▍        | 14/100 [10:18<1:03:39, 44.42s/it]
#
# Simulation cycles:  15%|█▌        | 15/100 [12:58<1:52:14, 79.23s/it]
#
# Simulation cycles:  16%|█▌        | 16/100 [47:03<15:39:13, 670.88s/it]
#
# Simulation cycles:  17%|█▋        | 17/100 [48:36<11:27:36, 497.06s/it]
#
# Simulation cycles:  18%|█▊        | 18/100 [49:35<8:19:42, 365.64s/it]
#
# Simulation cycles:  19%|█▉        | 19/100 [51:17<6:26:39, 286.42s/it]
#
# Simulation cycles:  20%|██        | 20/100 [52:17<4:51:20, 218.50s/it]
#
# Simulation cycles:  21%|██        | 21/100 [53:00<3:37:56, 165.53s/it]
#
# Simulation cycles:  22%|██▏       | 22/100 [53:43<2:47:40, 128.98s/it]
#
# Simulation cycles:  23%|██▎       | 23/100 [54:33<2:15:04, 105.26s/it]
#
# Simulation cycles:  24%|██▍       | 24/100 [55:17<1:49:50, 86.72s/it]
#
# Simulation cycles:  25%|██▌       | 25/100 [55:59<1:31:37, 73.30s/it]
#
# Simulation cycles:  26%|██▌       | 26/100 [56:47<1:21:07, 65.78s/it]
#
# Simulation cycles:  27%|██▋       | 27/100 [57:31<1:12:14, 59.38s/it]
#
# Simulation cycles:  28%|██▊       | 28/100 [58:21<1:07:36, 56.34s/it]
#
# Simulation cycles:  29%|██▉       | 29/100 [59:05<1:02:34, 52.88s/it]
#
# Simulation cycles:  30%|███       | 30/100 [59:50<58:39, 50.28s/it]
#
# Simulation cycles:  31%|███       | 31/100 [1:00:36<56:36, 49.23s/it]
#
# Simulation cycles:  32%|███▏      | 32/100 [1:01:20<53:55, 47.59s/it]
#
# Simulation cycles:  33%|███▎      | 33/100 [1:02:07<52:54, 47.38s/it]
#
# Simulation cycles:  34%|███▍      | 34/100 [1:02:51<51:01, 46.39s/it]
#
# Simulation cycles:  35%|███▌      | 35/100 [1:03:39<50:52, 46.95s/it]
#
# Simulation cycles:  36%|███▌      | 36/100 [1:04:25<49:39, 46.56s/it]
#
# Simulation cycles:  37%|███▋      | 37/100 [1:05:11<48:44, 46.41s/it]
#
# Simulation cycles:  38%|███▊      | 38/100 [1:05:58<48:13, 46.68s/it]
#
# Simulation cycles:  39%|███▉      | 39/100 [1:06:43<46:55, 46.15s/it]
#
# Simulation cycles:  40%|████      | 40/100 [1:07:30<46:26, 46.44s/it]
#
# Simulation cycles:  41%|████      | 41/100 [1:08:16<45:15, 46.03s/it]
#
# Simulation cycles:  42%|████▏     | 42/100 [1:09:08<46:17, 47.88s/it]
#
# Simulation cycles:  43%|████▎     | 43/100 [1:09:54<45:09, 47.53s/it]
#
# Simulation cycles:  44%|████▍     | 44/100 [1:10:43<44:40, 47.87s/it]
#
# Simulation cycles:  45%|████▌     | 45/100 [1:11:29<43:26, 47.39s/it]
#
# Simulation cycles:  46%|████▌     | 46/100 [1:12:16<42:25, 47.14s/it]
#
# Simulation cycles:  47%|████▋     | 47/100 [1:13:04<41:50, 47.36s/it]
#
# Simulation cycles:  48%|████▊     | 48/100 [1:14:03<44:13, 51.02s/it]
#
# Simulation cycles:  49%|████▉     | 49/100 [1:14:49<42:00, 49.43s/it]
#
# Simulation cycles:  50%|█████     | 50/100 [1:15:36<40:34, 48.68s/it]
#
# Simulation cycles:  51%|█████     | 51/100 [1:16:23<39:20, 48.18s/it]
#
# Simulation cycles:  52%|█████▏    | 52/100 [1:17:12<38:40, 48.34s/it]
#
# Simulation cycles:  53%|█████▎    | 53/100 [1:18:05<39:00, 49.81s/it]
#
# Simulation cycles:  54%|█████▍    | 54/100 [1:18:59<39:14, 51.18s/it]
#
# Simulation cycles:  55%|█████▌    | 55/100 [1:19:49<38:05, 50.80s/it]
#
# Simulation cycles:  56%|█████▌    | 56/100 [1:20:41<37:28, 51.11s/it]
#
# Simulation cycles:  57%|█████▋    | 57/100 [1:21:30<36:15, 50.60s/it]
#
# Simulation cycles:  58%|█████▊    | 58/100 [1:22:20<35:10, 50.25s/it]
#
# Simulation cycles:  59%|█████▉    | 59/100 [1:23:12<34:49, 50.95s/it]
#
# Simulation cycles:  60%|██████    | 60/100 [1:24:07<34:35, 51.89s/it]
#
# Simulation cycles:  61%|██████    | 61/100 [1:24:56<33:10, 51.04s/it]
#
# Simulation cycles:  62%|██████▏   | 62/100 [1:25:44<31:45, 50.14s/it]
#
# Simulation cycles:  63%|██████▎   | 63/100 [1:26:35<31:11, 50.59s/it]
#
# Simulation cycles:  64%|██████▍   | 64/100 [1:27:27<30:34, 50.97s/it]
#
# Simulation cycles:  65%|██████▌   | 65/100 [1:28:16<29:23, 50.38s/it]
#
# Simulation cycles:  66%|██████▌   | 66/100 [1:29:05<28:16, 49.89s/it]
#
# Simulation cycles:  67%|██████▋   | 67/100 [1:29:54<27:13, 49.50s/it]
#
# Simulation cycles:  68%|██████▊   | 68/100 [1:30:43<26:24, 49.52s/it]
#
# Simulation cycles:  69%|██████▉   | 69/100 [1:31:33<25:35, 49.53s/it]
#
# Simulation cycles:  70%|███████   | 70/100 [1:32:21<24:38, 49.28s/it]
#
# Simulation cycles:  71%|███████   | 71/100 [1:33:15<24:29, 50.66s/it]
#
# Simulation cycles:  72%|███████▏  | 72/100 [1:34:08<23:56, 51.30s/it]
#
# Simulation cycles:  73%|███████▎  | 73/100 [1:35:07<24:09, 53.69s/it]
#
# Simulation cycles:  74%|███████▍  | 74/100 [1:36:03<23:32, 54.32s/it]
#
# Simulation cycles:  75%|███████▌  | 75/100 [1:36:56<22:24, 53.78s/it]
#
# Simulation cycles:  76%|███████▌  | 76/100 [1:37:48<21:21, 53.42s/it]
#
# Simulation cycles:  77%|███████▋  | 77/100 [1:38:39<20:12, 52.72s/it]
#
# Simulation cycles:  78%|███████▊  | 78/100 [1:39:29<19:01, 51.87s/it]
#
# Simulation cycles:  79%|███████▉  | 79/100 [1:40:19<17:54, 51.18s/it]
#
# Simulation cycles:  80%|████████  | 80/100 [1:41:09<16:59, 51.00s/it]
#
# Simulation cycles:  81%|████████  | 81/100 [1:42:02<16:16, 51.40s/it]
#
# Simulation cycles:  82%|████████▏ | 82/100 [1:42:55<15:33, 51.88s/it]
#
# Simulation cycles:  83%|████████▎ | 83/100 [1:43:47<14:42, 51.91s/it]
#
# Simulation cycles:  84%|████████▍ | 84/100 [1:44:40<13:57, 52.32s/it]
#
# Simulation cycles:  85%|████████▌ | 85/100 [1:45:33<13:06, 52.45s/it]
#
# Simulation cycles:  86%|████████▌ | 86/100 [1:46:28<12:27, 53.39s/it]
#
# Simulation cycles:  87%|████████▋ | 87/100 [1:47:25<11:46, 54.33s/it]
#
# Simulation cycles:  88%|████████▊ | 88/100 [1:48:24<11:08, 55.69s/it]
#
# Simulation cycles:  89%|████████▉ | 89/100 [1:49:25<10:32, 57.53s/it]
#
# Simulation cycles:  90%|█████████ | 90/100 [1:50:36<10:14, 61.49s/it]
#
# Simulation cycles:  91%|█████████ | 91/100 [1:51:50<09:45, 65.09s/it]
#
# Simulation cycles:  92%|█████████▏| 92/100 [1:52:59<08:51, 66.38s/it]
#
# Simulation cycles:  93%|█████████▎| 93/100 [1:54:02<07:37, 65.42s/it]
#
# Simulation cycles:  94%|█████████▍| 94/100 [1:55:09<06:34, 65.69s/it]
#
# Simulation cycles:  95%|█████████▌| 95/100 [1:56:13<05:26, 65.26s/it]
#
# Simulation cycles:  96%|█████████▌| 96/100 [1:57:23<04:27, 66.80s/it]
#
# Simulation cycles:  97%|█████████▋| 97/100 [1:58:32<03:21, 67.29s/it]
#
# Simulation cycles:  98%|█████████▊| 98/100 [1:59:35<02:12, 66.14s/it]
#
# Simulation cycles:  99%|█████████▉| 99/100 [2:00:48<01:08, 68.21s/it]
#
# Simulation cycles: 100%|██████████| 100/100 [2:01:59<00:00, 69.03s/it]
#
#
# Variables in Matrix_GEN_M0_all:  33%|███▎      | 4/12 [4:02:23<9:38:07, 4335.96s/it]
#
# Simulation cycles:   0%|          | 0/100 [00:00<?, ?it/s]
#
# Simulation cycles:   1%|          | 1/100 [00:45<1:15:41, 45.88s/it]
#
# Simulation cycles:   2%|▏         | 2/100 [01:33<1:16:35, 46.90s/it]
#
# Simulation cycles:   3%|▎         | 3/100 [02:20<1:16:15, 47.17s/it]
#
# Simulation cycles:   4%|▍         | 4/100 [03:11<1:17:36, 48.51s/it]
#
# Simulation cycles:   5%|▌         | 5/100 [04:02<1:17:56, 49.22s/it]
#
# Simulation cycles:   6%|▌         | 6/100 [04:50<1:16:51, 49.06s/it]
#
# Simulation cycles:   7%|▋         | 7/100 [05:39<1:15:55, 48.98s/it]
#
# Simulation cycles:   8%|▊         | 8/100 [06:30<1:15:52, 49.48s/it]
#
# Simulation cycles:   9%|▉         | 9/100 [07:19<1:15:11, 49.57s/it]
#
# Simulation cycles:  10%|█         | 10/100 [08:06<1:13:00, 48.67s/it]
#
# Simulation cycles:  11%|█         | 11/100 [08:53<1:11:15, 48.04s/it]
#
# Simulation cycles:  12%|█▏        | 12/100 [09:42<1:10:54, 48.35s/it]
#
# Simulation cycles:  13%|█▎        | 13/100 [10:30<1:10:11, 48.40s/it]
#
# Simulation cycles:  14%|█▍        | 14/100 [11:18<1:08:53, 48.07s/it]
#
# Simulation cycles:  15%|█▌        | 15/100 [12:09<1:09:41, 49.19s/it]
#
# Simulation cycles:  16%|█▌        | 16/100 [13:00<1:09:25, 49.59s/it]
#
# Simulation cycles:  17%|█▋        | 17/100 [13:51<1:09:12, 50.02s/it]
#
# Simulation cycles:  18%|█▊        | 18/100 [14:43<1:09:01, 50.51s/it]
#
# Simulation cycles:  19%|█▉        | 19/100 [15:33<1:08:05, 50.44s/it]
#
# Simulation cycles:  20%|██        | 20/100 [16:21<1:06:13, 49.66s/it]
#
# Simulation cycles:  21%|██        | 21/100 [17:08<1:04:38, 49.10s/it]
#
# Simulation cycles:  22%|██▏       | 22/100 [17:55<1:02:47, 48.30s/it]
#
# Simulation cycles:  23%|██▎       | 23/100 [18:41<1:01:00, 47.54s/it]
#
# Simulation cycles:  24%|██▍       | 24/100 [19:30<1:00:57, 48.13s/it]
#
# Simulation cycles:  25%|██▌       | 25/100 [20:26<1:02:53, 50.31s/it]
#
# Simulation cycles:  26%|██▌       | 26/100 [21:16<1:02:00, 50.27s/it]
#
# Simulation cycles:  27%|██▋       | 27/100 [22:05<1:00:44, 49.92s/it]
#
# Simulation cycles:  28%|██▊       | 28/100 [22:57<1:00:32, 50.45s/it]
#
# Simulation cycles:  29%|██▉       | 29/100 [23:49<1:00:32, 51.16s/it]
#
# Simulation cycles:  30%|███       | 30/100 [24:41<59:59, 51.42s/it]
#
# Simulation cycles:  31%|███       | 31/100 [25:34<59:23, 51.65s/it]
#
# Simulation cycles:  32%|███▏      | 32/100 [26:24<57:57, 51.14s/it]
#
# Simulation cycles:  33%|███▎      | 33/100 [27:12<56:19, 50.44s/it]
#
# Simulation cycles:  34%|███▍      | 34/100 [28:01<55:01, 50.02s/it]
#
# Simulation cycles:  35%|███▌      | 35/100 [28:52<54:21, 50.17s/it]
#
# Simulation cycles:  36%|███▌      | 36/100 [29:46<54:51, 51.42s/it]
#
# Simulation cycles:  37%|███▋      | 37/100 [30:42<55:17, 52.67s/it]
#
# Simulation cycles:  38%|███▊      | 38/100 [31:34<54:16, 52.53s/it]
#
# Simulation cycles:  39%|███▉      | 39/100 [32:27<53:35, 52.71s/it]
#
# Simulation cycles:  40%|████      | 40/100 [33:25<54:19, 54.32s/it]
#
# Simulation cycles:  41%|████      | 41/100 [34:21<53:45, 54.68s/it]
#
# Simulation cycles:  42%|████▏     | 42/100 [35:24<55:19, 57.23s/it]
#
# Simulation cycles:  43%|████▎     | 43/100 [36:21<54:25, 57.29s/it]
#
# Simulation cycles:  44%|████▍     | 44/100 [37:19<53:32, 57.37s/it]
#
# Simulation cycles:  45%|████▌     | 45/100 [38:12<51:24, 56.07s/it]
#
# Simulation cycles:  46%|████▌     | 46/100 [39:06<50:01, 55.59s/it]
#
# Simulation cycles:  47%|████▋     | 47/100 [40:11<51:29, 58.30s/it]
#
# Simulation cycles:  48%|████▊     | 48/100 [41:11<50:56, 58.77s/it]
#
# Simulation cycles:  49%|████▉     | 49/100 [42:11<50:17, 59.17s/it]
#
# Simulation cycles:  50%|█████     | 50/100 [43:11<49:36, 59.53s/it]
#
# Simulation cycles:  51%|█████     | 51/100 [44:11<48:43, 59.66s/it]
#
# Simulation cycles:  52%|█████▏    | 52/100 [45:13<48:06, 60.13s/it]
#
# Simulation cycles:  53%|█████▎    | 53/100 [46:13<47:04, 60.10s/it]
#
# Simulation cycles:  54%|█████▍    | 54/100 [47:19<47:28, 61.92s/it]
#
# Simulation cycles:  55%|█████▌    | 55/100 [48:21<46:36, 62.16s/it]
#
# Simulation cycles:  56%|█████▌    | 56/100 [49:26<46:09, 62.95s/it]
#
# Simulation cycles:  57%|█████▋    | 57/100 [50:37<46:46, 65.26s/it]
#
# Simulation cycles:  58%|█████▊    | 58/100 [51:44<46:08, 65.92s/it]
#
# Simulation cycles:  59%|█████▉    | 59/100 [52:47<44:17, 64.83s/it]
#
# Simulation cycles:  60%|██████    | 60/100 [53:45<41:54, 62.87s/it]
#
# Simulation cycles:  61%|██████    | 61/100 [54:44<40:07, 61.72s/it]
#
# Simulation cycles:  62%|██████▏   | 62/100 [55:38<37:42, 59.53s/it]
#
# Simulation cycles:  63%|██████▎   | 63/100 [56:33<35:46, 58.02s/it]
#
# Simulation cycles:  64%|██████▍   | 64/100 [57:27<34:08, 56.91s/it]
#
# Simulation cycles:  65%|██████▌   | 65/100 [58:25<33:16, 57.03s/it]
#
# Simulation cycles:  66%|██████▌   | 66/100 [59:24<32:48, 57.88s/it]

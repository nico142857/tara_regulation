# %%
import pandas as pd

input_dir = '../../../out_results/out_correlation/'
input_list_path = '../../../out_results/out_shap_values/list_from_shap_correlated.tsv'
output_file_path = '../../../out_results/out_shap_values/list_from_shap_correlated_env.tsv'

shap_correlated_df = pd.read_csv(input_list_path, sep='\t')

# %%
shap_correlated_df = pd.read_csv(input_list_path, sep='\t')
shap_correlated_df
# Out:
#    matrix_type     subsample target_variable  \
# 0           M0           srf           Polar
# 1           M0           srf     Temperature
# 2           M0           srf        Province
# 3           M0      nonpolar           Layer
# 4           M0      nonpolar          Layer2
# 5           M0  epi-nonpolar             NO3
# 6           M0  epi-nonpolar      CarbonFlux
# 7           M0  epi-nonpolar             NPP
# 8           M1           srf           Polar
# 9           M1           srf     Temperature
# 10          M1           srf        Province
# 11          M1      nonpolar           Layer
# 12          M1      nonpolar          Layer2
# 13          M1  epi-nonpolar             NO3
# 14          M1  epi-nonpolar      CarbonFlux
# 15          M1  epi-nonpolar             NPP
# 16      stress           srf           Polar
# 17      stress           srf     Temperature
# 18      stress           srf        Province
# 19      stress      nonpolar           Layer
# 20      stress      nonpolar          Layer2
# 21      stress  epi-nonpolar             NO3
# 22      stress  epi-nonpolar      CarbonFlux
# 23      stress  epi-nonpolar             NPP
# 24       guidi           srf           Polar
# 25       guidi           srf     Temperature
# 26       guidi           srf        Province
# 27       guidi      nonpolar           Layer
# 28       guidi      nonpolar          Layer2
# 29       guidi  epi-nonpolar             NO3
# 30       guidi  epi-nonpolar      CarbonFlux
# 31       guidi  epi-nonpolar             NPP
# 32     salazar           srf           Polar
# 33     salazar           srf     Temperature
# 34     salazar           srf        Province
# 35     salazar      nonpolar           Layer
# 36     salazar      nonpolar          Layer2
# 37     salazar  epi-nonpolar             NO3
# 38     salazar  epi-nonpolar      CarbonFlux
# 39     salazar  epi-nonpolar             NPP
# 40          MX           srf           Polar
# 41          MX           srf     Temperature
# 42          MX           srf        Province
# 43          MX      nonpolar           Layer
# 44          MX      nonpolar          Layer2
# 45          MX  epi-nonpolar             NO3
# 46          MX  epi-nonpolar      CarbonFlux
# 47          MX  epi-nonpolar             NPP
#
#                               shap_top_tfs  \
# 0             AgaR, LiuR, KdgR, AraR, TyrR
# 1             AgaR, HrcA, LexA, RbsR, PhnR
# 2        AgaR, HypR, CadR-PbrR, NrdR, GguR
# 3   MetR, FnrN_FixK, ExuR_UxuR, FixJ, PdxR
# 4             MetR, PaaR, NrtR, PdxR, GntR
# 5             BioQ, AmtR, NagR, NorR, NnrR
# 6             GlcC, ThiR, MntR, FadR, SdaR
# 7             NagC, FabR, NtrC, VanR, NorR
# 8             LexA, AgaR, CsoR, PrpR, PurR
# 9             HrcA, LexA, AgaR, TrpR, LiuQ
# 10            AgaR, LexA, LiuR, HypR, PhnF
# 11       BirA, KdgR, FnrN_FixK, VanR, FadP
# 12            BirA, MerR, KdgR, LexA, GulR
# 13       CadR-PbrR, CzrA, PhsR, TyrR, NmlR
# 14             PdhR, Irr, GulR, NmlR, PaaR
# 15       NagC, VanR, GlcC, FnrN_FixK, ThiR
# 16            MetR, HypR, PhnF, PurR, AcnR
# 17            NrdR, MetJ, PurR, AcnR, LexA
# 18            PurR, HutC, NtrC, MetR, HcpR
# 19            BirA, CsoR, PdxR, MerR, LiuQ
# 20            CsoR, MerR, BirA, LiuQ, SiaR
# 21            LtbR, GlcC, NmlR, NiaR, GulR
# 22       BioQ, NtrC, SahR_SamR, CblR, LtbR
# 23            AgaR, AmtR, NikR, LiuR, RutR
# 24        SahR_SamR, GguR, Zur, TrpR, SoxR
# 25        SahR_SamR, FUR, TyrR, PhnF, PdxR
# 26       SahR_SamR, PhnF, KdgR, TyrR, GguR
# 27            NagC, PhnF, ArgR, NrtR, PdxR
# 28            ArgR, FixJ, NifA, NrtR, PhnF
# 29            ZntR, FadP, HypR, NmlR, LldR
# 30       TyrR, AmtR, SahR_SamR, NnrR, PdhR
# 31            FabR, FadR, FixJ, MerR, NsrR
# 32             LiuQ, TyrR, Irr, BirA, NtrC
# 33             Irr, AgaR, NagQ, NmlR, CcpA
# 34            FabR, FadR, AgaR, PsrA, PurR
# 35            LiuQ, AcnR, KdgR, NmlR, NifA
# 36        KdgR, NifA, AcnR, Irr, CadR-PbrR
# 37            FabR, PaaR, PhnR, NorR, BioQ
# 38             Phr, AraR, CueR, PurR, NagQ
# 39            NadQ, LtbR, NmlR, HypR, NnrR
# 40            PurR, AgaR, VanR, FadR, QorR
# 41            AgaR, PurR, FabR, LiuQ, SdaR
# 42       AgaR, ExuR_UxuR, FabR, PurR, TrpR
# 43       GlcC, CadR-PbrR, FadR, PhnR, NrdR
# 44            GlcC, PaaR, GntR, FadR, TtrR
# 45            DasR, MetJ, PhsR, VanR, BioQ
# 46            TrpR, AmtR, TtrR, IscR, LexA
# 47            MetR, PurR, NsrR, LiuQ, GlcC
#
#                               shap_top_tfs_correlated
# 0   AgaR, SahR_SamR, NtrC, FUR, NagC, NnrR, LiuR, ...
# 1   AgaR, SahR_SamR, NtrC, FUR, NagC, NnrR, HrcA, ...
# 2   AgaR, SahR_SamR, NtrC, FUR, NagC, NnrR, HypR, ...
# 3   MetR, FUR, KdgR, ThiR, NagC, NrtR, FnrN_FixK, ...
# 4   MetR, FUR, KdgR, ThiR, NagC, NrtR, PaaR, BirA,...
# 5   BioQ, NrtR, MntR, Zur, SahR_SamR, KdgR, AmtR, ...
# 6   GlcC, Phr, MntR, XylR, BirA, NrtR, ThiR, NagC,...
# 7   NagC, NrtR, ThiR, MntR, FUR, KdgR, FabR, GntR,...
# 8   LexA, AgaR, GguR, LiuR, FabR, HexR, AgaR, SahR...
# 9   HrcA, NtrC, KdgR, AgaR, MetR, XylR, LexA, AgaR...
# 10  AgaR, SahR_SamR, NtrC, LiuR, NnrR, FUR, LexA, ...
# 11  BirA, NsrR, NagC, SahR_SamR, Phr, NrtR, KdgR, ...
# 12  BirA, NsrR, NagC, SahR_SamR, Phr, NrtR, MerR, ...
# 13  CadR-PbrR, FixJ, PdhR, NarP, NiaR, TyrR, CzrA,...
# 14  PdhR, PhnR, LldR, HutC, PhnF, HexR, Irr, NagC,...
# 15  NagC, NrtR, MntR, KdgR, FUR, ArgR, VanR, HypR,...
# 16  MetR, FUR, SahR_SamR, NsrR, NrtR, NrdR, HypR, ...
# 17  NrdR, NrtR, KdgR, FUR, NagC, ArgR, MetJ, HisR,...
# 18  PurR, NifA, FadP, MetR, GulR, ExuR_UxuR, HutC,...
# 19  BirA, NagC, NrtR, MetR, MntR, SahR_SamR, CsoR,...
# 20  CsoR, MetR, Phr, NagC, PurR, CzrA, MerR, CueR,...
# 21  LtbR, PhnR, NnrR, AraR, CzrA, DasR, GlcC, LldR...
# 22  BioQ, GlcC, FabR, NiaR, LldR, PaaR, NtrC, LldR...
# 23  AgaR, ArgR, Zur, MntR, CzrA, NrtR, AmtR, NsrR,...
# 24  SahR_SamR, FUR, ArgR, NrtR, MetR, NsrR, GguR, ...
# 25  SahR_SamR, FUR, ArgR, NrtR, MetR, NsrR, FUR, N...
# 26  SahR_SamR, FUR, ArgR, NrtR, MetR, NsrR, PhnF, ...
# 27  NagC, NrtR, FUR, MntR, KdgR, NsrR, PhnF, KdgR,...
# 28  ArgR, MntR, SahR_SamR, CzrA, KdgR, NagC, FixJ,...
# 29  ZntR, PhsR, DasR, MetR, NnrR, GguR, FadP, BirA...
# 30  TyrR, BirA, NarP, IscR, KdgR, PsrA, AmtR, SoxR...
# 31  FabR, AgaR, NagR, MerR, PdxR, FadP, FadR, IscR...
# 32  LiuQ, NifA, MetR, KdgR, NiaR, HcpR, TyrR, PhnF...
# 33  Irr, TyrR, Rex, BirA, MetR, XylR, AgaR, NagC, ...
# 34  FabR, ModE, PhnR, LldR, NrtR, ThiR, FadR, NiaR...
# 35  LiuQ, NtrC, BirA, KdgR, MetR, FUR, AcnR, RbkR,...
# 36  KdgR, NagC, NrtR, FUR, SahR_SamR, Zur, NifA, N...
# 37  FabR, PhnF, CblR, ModE, XylR, TyrR, PaaR, Zur,...
# 38  Phr, BirA, Zur, ArgR, NrtR, FUR, AraR, NrtR, I...
# 39  NadQ, ArgR, MetR, NagC, LexA, SahR_SamR, LtbR,...
# 40  PurR, MetR, FUR, LiuR, SahR_SamR, GulR, AgaR, ...
# 41  AgaR, MetR, GulR, SahR_SamR, FUR, KdgR, PurR, ...
# 42  AgaR, MetR, GulR, SahR_SamR, FUR, KdgR, ExuR_U...
# 43  GlcC, NrtR, ArgR, MntR, Phr, RbkR, CadR-PbrR, ...
# 44  GlcC, NrtR, ArgR, MntR, Phr, RbkR, PaaR, SahR_...
# 45  DasR, NrtR, ArgR, Phr, Zur, MntR, MetJ, FixJ, ...
# 46  TrpR, HutC, ModE, HexR, PhrR, PhnF, AmtR, GntR...
# 47  MetR, FUR, KdgR, NagC, MntR, IscR, PurR, NnrR,...

# %%
import pandas as pd
import os

# Define the file paths
correlation_dir = '../../../out_results/out_correlation/correlation_bio_env'
input_list_path = '../../../out_results/out_shap_values/list_from_shap_correlated.tsv'
output_file_path = '../../../out_results/out_shap_values/list_from_shap_correlated_env.tsv'

# Read the input file into a DataFrame
shap_correlated_df = pd.read_csv(input_list_path, sep='\t')

# Initialize an empty list to store the top_tfs_correlated lists
top_tfs_correlated_lists = []

# Create a mapping for the column names
column_mapping = {
    'CarbonFlux': 'Mean Flux at 150m',
    'NPP': 'NPP 8d VGPM (mgC/m2/day)'
}

threshold = 0.7

# Iterate over each row in the DataFrame
for index, row in shap_correlated_df.iterrows():
    # Extract variables from the current row
    matrix_type = row['matrix_type']
    subsample = row['subsample']
    target_variable = row['target_variable']
    
    # Check if the target variable is one of the continuous variables
    if target_variable in ['Temperature', 'NO3', 'CarbonFlux', 'NPP']:
        # Map the target variable to the column name in the correlation file
        if target_variable in column_mapping:
            target_variable_name = column_mapping[target_variable]
        else:
            target_variable_name = target_variable
        
        # Construct the file path
        file_path = os.path.join(correlation_dir, f'corr_bio_env_heatmap_{matrix_type}_{subsample}.tsv')
        
        # Read the correlation file into a DataFrame
        correlation_df = pd.read_csv(file_path, sep='\t', index_col=0)
        
        # Filter the DataFrame based on the absolute value of the target variable
        filtered_indices = correlation_df[abs(correlation_df[target_variable_name]) >= threshold][target_variable_name].index.tolist()
        
        # Join the filtered indices into a comma-separated list
        lista = ', '.join(filtered_indices)
    else:
        # For non-continuous variables, leave the list empty
        lista = ''
    
    # Append the result to the list
    top_tfs_correlated_lists.append(lista)

# Add the new column to the DataFrame
shap_correlated_df['top_tfs_correlated'] = top_tfs_correlated_lists

# Save the updated DataFrame to a TSV file
shap_correlated_df.to_csv(output_file_path, sep='\t', index=False)

# Print a confirmation message
print(f"Updated DataFrame saved to {output_file_path}")
# Out:
# Updated DataFrame saved to ../../../out_results/out_shap_values/list_from_shap_correlated_env.tsv
